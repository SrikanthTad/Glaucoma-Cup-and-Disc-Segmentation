# %%
tf.config.list_physical_devices(
    device_type=None
)

tf.device(
    device_name
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 6
#       1 tf.config.list_physical_devices(
#       2     device_type=None
#       3 )
#       5 tf.device(
# ----> 6     device_name
#       7 )
#
# NameError: name 'device_name' is not defined

# %%
# !nvidia-smi
# Out:
# Mon Apr 24 19:23:54 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.45.01    Driver Version: 455.45.01    CUDA Version: 11.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  GeForce RTX 3090    Off  | 00000000:1B:00.0 Off |                  N/A |
# | 30%   24C    P8     9W / 350W |      2MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   1  GeForce RTX 3090    Off  | 00000000:3E:00.0 Off |                  N/A |
# | 30%   22C    P8     9W / 350W |   1781MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   2  GeForce RTX 3090    Off  | 00000000:89:00.0 Off |                  N/A |
# | 30%   21C    P8     9W / 350W |   6976MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
# |   3  GeForce RTX 3090    Off  | 00000000:B2:00.0 Off |                  N/A |
# | 30%   21C    P8     8W / 350W |      2MiB / 24268MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A   3931577      C   ...li12/.envs/new/bin/python        0MiB |
# |    0   N/A  N/A   3936355      C   ...li12/.envs/new/bin/python        0MiB |
# |    0   N/A  N/A   3936570      C   ...li12/.envs/new/bin/python        0MiB |
# |    0   N/A  N/A   3938105      C   ...li12/.envs/new/bin/python        0MiB |
# |    0   N/A  N/A   3956237      C   ...li12/.envs/new/bin/python        0MiB |
# |    1   N/A  N/A   3931577      C   ...li12/.envs/new/bin/python        0MiB |
# |    1   N/A  N/A   3936355      C   ...li12/.envs/new/bin/python     1779MiB |
# |    1   N/A  N/A   3936570      C   ...li12/.envs/new/bin/python        0MiB |
# |    1   N/A  N/A   3938105      C   ...li12/.envs/new/bin/python        0MiB |
# |    1   N/A  N/A   3956237      C   ...li12/.envs/new/bin/python        0MiB |
# |    2   N/A  N/A   3931577      C   ...li12/.envs/new/bin/python     1717MiB |
# |    2   N/A  N/A   3936355      C   ...li12/.envs/new/bin/python        0MiB |
# |    2   N/A  N/A   3936570      C   ...li12/.envs/new/bin/python     1759MiB |
# |    2   N/A  N/A   3938105      C   ...li12/.envs/new/bin/python     1759MiB |
# |    2   N/A  N/A   3956237      C   ...li12/.envs/new/bin/python     1739MiB |
# |    3   N/A  N/A   3931577      C   ...li12/.envs/new/bin/python        0MiB |
# |    3   N/A  N/A   3936355      C   ...li12/.envs/new/bin/python        0MiB |
# |    3   N/A  N/A   3936570      C   ...li12/.envs/new/bin/python        0MiB |
# |    3   N/A  N/A   3938105      C   ...li12/.envs/new/bin/python        0MiB |
# |    3   N/A  N/A   3956237      C   ...li12/.envs/new/bin/python        0MiB |
# +-----------------------------------------------------------------------------+

# %%
import cv2
import tensorflow as tf
import numpy as np
import os
import matplotlib.pyplot as plt
# Out:
# 2023-04-24 19:26:03.040722: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-24 19:26:03.106940: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
IMAGE_DIR = "/data2/SrikanthData/ResearchWork2/tensorflow/Project/img_data/d1/Images"
MASK_DIR = "/data2/SrikanthData/ResearchWork2/tensorflow/Project/img_data/d1/Mask_disc"
BATCH_SIZE = 4

# %%
def double_conv_block(x, n_filters):
    # Conv2D then ReLU activation
    x = tf.keras.layers.Conv2D(
        n_filters,
        3,
        padding="same",
        activation="relu",
        kernel_initializer="he_normal"
    )(x)
    # Conv2D then ReLU activation
    x = tf.keras.layers.Conv2D(
        n_filters,
        3,
        padding="same",
        activation="relu",
        kernel_initializer="he_normal"
    )(x)
    return x

def downsample_block(x, n_filters):
    f = double_conv_block(x, n_filters)
    p = tf.keras.layers.MaxPool2D(2)(f)
    p = tf.keras.layers.Dropout(0.3)(p)
    return f, p

def upsample_block(x, conv_features, n_filters):
    # upsample
    x = tf.keras.layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
    # concatenate
    x = tf.keras.layers.concatenate([x, conv_features])
    # dropout
    x = tf.keras.layers.Dropout(0.3)(x)
    # Conv2D twice with ReLU activation
    x = double_conv_block(x, n_filters)
    return x

def create_unet():
    # inputs
    inputs = tf.keras.layers.Input(shape=(128,128,3))
    # encoder: contracting path - downsample
    # 1 - downsample
    f1, p1 = downsample_block(inputs, 32) # 64
    # 2 - downsample
    f2, p2 = downsample_block(p1, 64) # 128
    # 3 - downsample
    f3, p3 = downsample_block(p2, 128) # 256
    # 4 - downsample
    f4, p4 = downsample_block(p3, 256) # 512
    # 5 - bottleneck
    bottleneck = double_conv_block(p4, 256) # 1024

    # decoder: expanding path - upsample
    # 6 - upsample
    u6 = upsample_block(bottleneck, f4, 256) # 512
    # 7 - upsample
    u7 = upsample_block(u6, f3, 128) # 256
    # 8 - upsample
    u8 = upsample_block(u7, f2, 64) # 128
    # 9 - upsample
    u9 = upsample_block(u8, f1, 32)
    # outputs
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation = "sigmoid")(u9)
    # unet model with Keras Functional API
    unet_model = tf.keras.Model(inputs, outputs, name="U-Net")
    return unet_model

# %%
# load data
assert len(os.listdir(IMAGE_DIR)) == len(os.listdir(MASK_DIR)), "Different number of images and masks"
X, Y, file_names = [], [], []
for image_name in sorted(os.listdir(IMAGE_DIR)):
    mask_name = image_name[:-4] + "_ODsegSoftmap.png"
    

    image = cv2.imread(os.path.join(IMAGE_DIR, image_name))
    image = cv2.resize(image, (256, 256))
    

    mask = cv2.imread(os.path.join(MASK_DIR, mask_name))
    mask = cv2.resize(mask, (256, 256))


    X.append(image)
    Y.append(mask)
    file_names.append(image_name)

# %%
def dice_coef(y_true, y_pred): # accuracy function 
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + 1e-6) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + 1e-6)
  
def dice_loss(y_true,y_pred): # loss function 
    return -dice_coef(y_true,y_pred)
  
def log_dice_loss(y_true, y_pred):
    return -tf.math.log(dice_coef(y_true, y_pred))



def iou(y_true, y_pred, threshold=0.5):                                                             
    y_true = tf.reshape(y_true, [-1])                                                               
    y_true = tf.cast(y_true, tf.float32)                                                            
    y_pred = tf.cast(y_pred > threshold, tf.float32)                                                
                                                                                                    
    y_pred = tf.reshape(y_pred, [-1])                                                               
                                                                                                    
                                                                                                    
    intersection = tf.reduce_sum(y_true*y_pred)                                                     
    union = tf.reduce_sum(tf.cast(y_true + y_pred > 0, tf.float32))                                 
                                                                                                    
    return intersection/union

# %%
def augmentation_fn(image, mask, training=True):
    """
    Augmentation for training set only. random cropy 50% of the time, random flip 50% of the time
    """
    # change brightness

    image = image.copy()
    mask = mask.copy()
    if training:
        image = tf.image.random_brightness(image, 0.1)
        image = tf.image.random_hue(image, 0.1)
    
        seed = np.random.randint(0, 1000, (2, ))
        if np.random.rand() < 0.5:
            random_size = np.random.randint(210, 256) # this is because the size of the image is 256 
        
            image = tf.image.stateless_random_crop(image, [random_size, random_size, 3], seed=seed)
            mask = tf.image.stateless_random_crop(mask, [random_size, random_size, 3], seed=seed)

        if np.random.rand() < 0.5:
            image = tf.image.stateless_random_flip_up_down(image, seed)
            mask = tf.image.stateless_random_flip_up_down(mask, seed)


    image = tf.image.resize(image, (128, 128))/122.5 - 1.0
    mask = tf.cast(tf.image.resize(mask, (128, 128)) > 122.5, float)[:, :, :1]
    
    return image, mask

# %%
# Split train and test
mask = list(range(len(X)))
np.random.seed(0)
np.random.shuffle(mask)
n_train = int(0.8*len(mask))
X_train = [X[i] for i in mask[:n_train]]
Y_train = [Y[i] for i in mask[:n_train]]
name_train = [file_names[i] for i in mask[:n_train]]

X_test = [X[i] for i in mask[n_train:]]
Y_test = [Y[i] for i in mask[n_train:]]
name_test = [file_names[i] for i in mask[n_train:]]

def data_generator(X, Y, batch_size=BATCH_SIZE, training=True):
    n_data = len(X)

    i = 0
    while True:
        if i + batch_size > n_data:
            i = 0
            mask = np.arange(n_data)
            np.random.shuffle(mask)

            X = [X[j] for j in mask]
            Y = [Y[j] for j in mask]
        
        mini_X = X[i: i + batch_size] 
        mini_Y = Y[i: i + batch_size]

        
        processed_data = [augmentation_fn(x, y, training) for x, y in zip(mini_X, mini_Y)]
        mini_X = [item[0] for item in processed_data]
        mini_Y = [item[1] for item in processed_data]


        mini_X = tf.concat([tf.expand_dims(_, axis=0) for _ in mini_X], axis=0)
        mini_Y = tf.concat([tf.expand_dims(_, axis=0) for _ in mini_Y], axis=0)

        i += batch_size
        yield mini_X, mini_Y

# %%
model = create_unet()

model.summary()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=log_dice_loss,
    metrics=[dice_coef, iou]
)

train_generator = data_generator(X_train, Y_train, training=True)
validation_generator = data_generator(X_test, Y_test, training=False)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)
history = model.fit(
    train_generator,
    epochs=300,
    validation_data=validation_generator,
    steps_per_epoch=len(X_train)//BATCH_SIZE,
    validation_steps=len(X_test)//BATCH_SIZE,
    callbacks=[early_stopping]
)
# Out:
# 2023-04-24 17:00:35.705764: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22288 MB memory:  -> device: 0, name: GeForce RTX 3090, pci bus id: 0000:1b:00.0, compute capability: 8.6
# 2023-04-24 17:00:35.707435: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 20509 MB memory:  -> device: 1, name: GeForce RTX 3090, pci bus id: 0000:3e:00.0, compute capability: 8.6
# 2023-04-24 17:00:35.708845: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 15314 MB memory:  -> device: 2, name: GeForce RTX 3090, pci bus id: 0000:89:00.0, compute capability: 8.6
# 2023-04-24 17:00:35.709934: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 22288 MB memory:  -> device: 3, name: GeForce RTX 3090, pci bus id: 0000:b2:00.0, compute capability: 8.6
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['conv2d_1[0][0]']
#
#  dropout (Dropout)              (None, 64, 64, 32)   0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 64)   18496       ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)  0           ['conv2d_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 64)   0           ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 128)  73856       ['dropout_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0          ['conv2d_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 128)  0           ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 256)  295168      ['dropout_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 256)  590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)   0           ['conv2d_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 8, 8, 256)    0           ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    590080      ['dropout_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 256)    590080      ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 256)  590080     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 512)  0           ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 256)  1179904     ['dropout_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 256)  590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 128)  295040     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 256)  0           ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 128)  295040      ['dropout_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 128)  147584      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 64)  73792       ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 128)  0           ['concatenate_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 64)   73792       ['dropout_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 64)   36928       ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 32  18464      ['conv2d_15[0][0]']
#  spose)                         )
#  concatenate_3 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 128, 128, 64  0           ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 32  18464       ['dropout_7[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 32  9248        ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 1)  33          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 5,680,865
# Trainable params: 5,680,865
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/300
# 2023-04-24 17:00:38.288545: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inU-Net/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-04-24 17:00:39.680119: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8401
# 2023-04-24 17:00:41.595967: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 20/20 [==============================] - 10s 56ms/step - loss: 2.5847 - dice_coef: 0.0777 - iou: 0.0458 - val_loss: 2.5145 - val_dice_coef: 0.0817 - val_iou: 0.1146
# Epoch 2/300
# 20/20 [==============================] - 1s 38ms/step - loss: 1.6754 - dice_coef: 0.2036 - iou: 0.1904 - val_loss: 2.8731 - val_dice_coef: 0.0638 - val_iou: 0.0049
# Epoch 3/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.8282 - dice_coef: 0.4518 - iou: 0.3288 - val_loss: 0.8620 - val_dice_coef: 0.4471 - val_iou: 0.3035
# Epoch 4/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.7881 - dice_coef: 0.4828 - iou: 0.3456 - val_loss: 1.4802 - val_dice_coef: 0.2420 - val_iou: 0.1418
# Epoch 5/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.4531 - dice_coef: 0.6454 - iou: 0.5085 - val_loss: 0.6138 - val_dice_coef: 0.5505 - val_iou: 0.3988
# Epoch 6/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.3814 - dice_coef: 0.6910 - iou: 0.5614 - val_loss: 0.9796 - val_dice_coef: 0.3911 - val_iou: 0.2466
# Epoch 7/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.3489 - dice_coef: 0.7136 - iou: 0.5804 - val_loss: 0.8609 - val_dice_coef: 0.4309 - val_iou: 0.2791
# Epoch 8/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.3454 - dice_coef: 0.7171 - iou: 0.5829 - val_loss: 0.8295 - val_dice_coef: 0.4506 - val_iou: 0.2997
# Epoch 9/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.3243 - dice_coef: 0.7281 - iou: 0.5860 - val_loss: 1.1685 - val_dice_coef: 0.3498 - val_iou: 0.2215
# Epoch 10/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.3440 - dice_coef: 0.7148 - iou: 0.5691 - val_loss: 0.6118 - val_dice_coef: 0.5487 - val_iou: 0.3843
# Epoch 11/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.2146 - dice_coef: 0.8095 - iou: 0.6957 - val_loss: 0.4465 - val_dice_coef: 0.6439 - val_iou: 0.4794
# Epoch 12/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.2062 - dice_coef: 0.8165 - iou: 0.7066 - val_loss: 0.5641 - val_dice_coef: 0.5788 - val_iou: 0.4228
# Epoch 13/300
# 20/20 [==============================] - 1s 35ms/step - loss: 0.2016 - dice_coef: 0.8202 - iou: 0.7103 - val_loss: 0.4970 - val_dice_coef: 0.6107 - val_iou: 0.4439
# Epoch 14/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1893 - dice_coef: 0.8304 - iou: 0.7210 - val_loss: 0.4831 - val_dice_coef: 0.6206 - val_iou: 0.4568
# Epoch 15/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1577 - dice_coef: 0.8549 - iou: 0.7575 - val_loss: 0.3495 - val_dice_coef: 0.7064 - val_iou: 0.5513
# Epoch 16/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1920 - dice_coef: 0.8292 - iou: 0.7224 - val_loss: 0.3708 - val_dice_coef: 0.6952 - val_iou: 0.5390
# Epoch 17/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1763 - dice_coef: 0.8404 - iou: 0.7371 - val_loss: 0.6230 - val_dice_coef: 0.5456 - val_iou: 0.3827
# Epoch 18/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1610 - dice_coef: 0.8530 - iou: 0.7524 - val_loss: 0.4036 - val_dice_coef: 0.6737 - val_iou: 0.5155
# Epoch 19/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.1398 - dice_coef: 0.8702 - iou: 0.7774 - val_loss: 0.2823 - val_dice_coef: 0.7554 - val_iou: 0.6117
# Epoch 20/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.1494 - dice_coef: 0.8633 - iou: 0.7695 - val_loss: 0.2438 - val_dice_coef: 0.7890 - val_iou: 0.6696
# Epoch 21/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.2751 - dice_coef: 0.7627 - iou: 0.6243 - val_loss: 0.1856 - val_dice_coef: 0.8326 - val_iou: 0.7195
# Epoch 22/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.3823 - dice_coef: 0.6981 - iou: 0.5552 - val_loss: 1.1481 - val_dice_coef: 0.3566 - val_iou: 0.2286
# Epoch 23/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.2619 - dice_coef: 0.7738 - iou: 0.6410 - val_loss: 0.4276 - val_dice_coef: 0.6556 - val_iou: 0.4921
# Epoch 24/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1704 - dice_coef: 0.8453 - iou: 0.7398 - val_loss: 0.6746 - val_dice_coef: 0.5259 - val_iou: 0.3680
# Epoch 25/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.1373 - dice_coef: 0.8723 - iou: 0.7797 - val_loss: 0.3219 - val_dice_coef: 0.7346 - val_iou: 0.5916
# Epoch 26/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1415 - dice_coef: 0.8691 - iou: 0.7739 - val_loss: 0.2956 - val_dice_coef: 0.7458 - val_iou: 0.5970
# Epoch 27/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1426 - dice_coef: 0.8681 - iou: 0.7737 - val_loss: 0.3740 - val_dice_coef: 0.6919 - val_iou: 0.5347
# Epoch 28/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1311 - dice_coef: 0.8778 - iou: 0.7872 - val_loss: 0.3645 - val_dice_coef: 0.6953 - val_iou: 0.5326
# Epoch 29/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1214 - dice_coef: 0.8864 - iou: 0.8005 - val_loss: 0.2785 - val_dice_coef: 0.7589 - val_iou: 0.6139
# Epoch 30/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1263 - dice_coef: 0.8820 - iou: 0.7928 - val_loss: 0.2621 - val_dice_coef: 0.7709 - val_iou: 0.6302
# Epoch 31/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1218 - dice_coef: 0.8862 - iou: 0.8011 - val_loss: 0.3241 - val_dice_coef: 0.7249 - val_iou: 0.5710
# Epoch 32/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1079 - dice_coef: 0.8985 - iou: 0.8203 - val_loss: 0.2521 - val_dice_coef: 0.7810 - val_iou: 0.6466
# Epoch 33/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.1261 - dice_coef: 0.8819 - iou: 0.7923 - val_loss: 0.2136 - val_dice_coef: 0.8077 - val_iou: 0.6785
# Epoch 34/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1174 - dice_coef: 0.8899 - iou: 0.8061 - val_loss: 0.1558 - val_dice_coef: 0.8560 - val_iou: 0.7516
# Epoch 35/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1235 - dice_coef: 0.8846 - iou: 0.7973 - val_loss: 0.2489 - val_dice_coef: 0.7822 - val_iou: 0.6467
# Epoch 36/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1067 - dice_coef: 0.8993 - iou: 0.8220 - val_loss: 0.1793 - val_dice_coef: 0.8378 - val_iou: 0.7266
# Epoch 37/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.1136 - dice_coef: 0.8932 - iou: 0.8109 - val_loss: 0.1818 - val_dice_coef: 0.8344 - val_iou: 0.7164
# Epoch 38/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1161 - dice_coef: 0.8911 - iou: 0.8082 - val_loss: 0.2231 - val_dice_coef: 0.8037 - val_iou: 0.6794
# Epoch 39/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1080 - dice_coef: 0.8982 - iou: 0.8181 - val_loss: 0.2610 - val_dice_coef: 0.7718 - val_iou: 0.6316
# Epoch 40/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0994 - dice_coef: 0.9058 - iou: 0.8317 - val_loss: 0.1544 - val_dice_coef: 0.8574 - val_iou: 0.7513
# Epoch 41/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.1104 - dice_coef: 0.8959 - iou: 0.8142 - val_loss: 0.1431 - val_dice_coef: 0.8674 - val_iou: 0.7698
# Epoch 42/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0949 - dice_coef: 0.9098 - iou: 0.8380 - val_loss: 0.2015 - val_dice_coef: 0.8176 - val_iou: 0.6918
# Epoch 43/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.1122 - dice_coef: 0.8948 - iou: 0.8148 - val_loss: 0.1072 - val_dice_coef: 0.8995 - val_iou: 0.8211
# Epoch 44/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1267 - dice_coef: 0.8821 - iou: 0.7941 - val_loss: 0.1458 - val_dice_coef: 0.8650 - val_iou: 0.7654
# Epoch 45/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1087 - dice_coef: 0.8976 - iou: 0.8173 - val_loss: 0.1128 - val_dice_coef: 0.8940 - val_iou: 0.8125
# Epoch 46/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0992 - dice_coef: 0.9060 - iou: 0.8316 - val_loss: 0.1259 - val_dice_coef: 0.8840 - val_iou: 0.7998
# Epoch 47/300
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0949 - dice_coef: 0.9097 - iou: 0.8370 - val_loss: 0.1057 - val_dice_coef: 0.9006 - val_iou: 0.8227
# Epoch 48/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.1023 - dice_coef: 0.9032 - iou: 0.8275 - val_loss: 0.1487 - val_dice_coef: 0.8623 - val_iou: 0.7587
# Epoch 49/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0954 - dice_coef: 0.9094 - iou: 0.8372 - val_loss: 0.2163 - val_dice_coef: 0.8084 - val_iou: 0.6834
# Epoch 50/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0896 - dice_coef: 0.9145 - iou: 0.8461 - val_loss: 0.1299 - val_dice_coef: 0.8784 - val_iou: 0.7854
# Epoch 51/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0829 - dice_coef: 0.9208 - iou: 0.8557 - val_loss: 0.1087 - val_dice_coef: 0.8989 - val_iou: 0.8216
# Epoch 52/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0866 - dice_coef: 0.9173 - iou: 0.8511 - val_loss: 0.0975 - val_dice_coef: 0.9077 - val_iou: 0.8335
# Epoch 53/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0904 - dice_coef: 0.9138 - iou: 0.8440 - val_loss: 0.0966 - val_dice_coef: 0.9081 - val_iou: 0.8340
# Epoch 54/300
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0851 - dice_coef: 0.9187 - iou: 0.8522 - val_loss: 0.0802 - val_dice_coef: 0.9232 - val_iou: 0.8579
# Epoch 55/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0795 - dice_coef: 0.9238 - iou: 0.8608 - val_loss: 0.1166 - val_dice_coef: 0.8917 - val_iou: 0.8096
# Epoch 56/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0809 - dice_coef: 0.9224 - iou: 0.8588 - val_loss: 0.0958 - val_dice_coef: 0.9089 - val_iou: 0.8341
# Epoch 57/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0897 - dice_coef: 0.9144 - iou: 0.8448 - val_loss: 0.1081 - val_dice_coef: 0.8979 - val_iou: 0.8161
# Epoch 58/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0860 - dice_coef: 0.9180 - iou: 0.8516 - val_loss: 0.1383 - val_dice_coef: 0.8710 - val_iou: 0.7726
# Epoch 59/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0901 - dice_coef: 0.9143 - iou: 0.8445 - val_loss: 0.1039 - val_dice_coef: 0.9016 - val_iou: 0.8215
# Epoch 60/300
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0947 - dice_coef: 0.9103 - iou: 0.8393 - val_loss: 0.0691 - val_dice_coef: 0.9334 - val_iou: 0.8767
# Epoch 61/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0891 - dice_coef: 0.9149 - iou: 0.8449 - val_loss: 0.0935 - val_dice_coef: 0.9114 - val_iou: 0.8409
# Epoch 62/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0836 - dice_coef: 0.9204 - iou: 0.8555 - val_loss: 0.0682 - val_dice_coef: 0.9343 - val_iou: 0.8787
# Epoch 63/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0834 - dice_coef: 0.9202 - iou: 0.8546 - val_loss: 0.0863 - val_dice_coef: 0.9174 - val_iou: 0.8485
# Epoch 64/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0776 - dice_coef: 0.9254 - iou: 0.8633 - val_loss: 0.1038 - val_dice_coef: 0.9020 - val_iou: 0.8241
# Epoch 65/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0777 - dice_coef: 0.9254 - iou: 0.8638 - val_loss: 0.0920 - val_dice_coef: 0.9121 - val_iou: 0.8398
# Epoch 66/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0797 - dice_coef: 0.9235 - iou: 0.8600 - val_loss: 0.1041 - val_dice_coef: 0.9015 - val_iou: 0.8223
# Epoch 67/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0758 - dice_coef: 0.9271 - iou: 0.8663 - val_loss: 0.1299 - val_dice_coef: 0.8800 - val_iou: 0.7894
# Epoch 68/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0796 - dice_coef: 0.9238 - iou: 0.8610 - val_loss: 0.0991 - val_dice_coef: 0.9067 - val_iou: 0.8320
# Epoch 69/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0772 - dice_coef: 0.9260 - iou: 0.8640 - val_loss: 0.0854 - val_dice_coef: 0.9186 - val_iou: 0.8515
# Epoch 70/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0734 - dice_coef: 0.9294 - iou: 0.8705 - val_loss: 0.0908 - val_dice_coef: 0.9138 - val_iou: 0.8436
# Epoch 71/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0753 - dice_coef: 0.9277 - iou: 0.8676 - val_loss: 0.0887 - val_dice_coef: 0.9156 - val_iou: 0.8453
# Epoch 72/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0744 - dice_coef: 0.9285 - iou: 0.8685 - val_loss: 0.0827 - val_dice_coef: 0.9209 - val_iou: 0.8546
# Epoch 73/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0700 - dice_coef: 0.9325 - iou: 0.8757 - val_loss: 0.0849 - val_dice_coef: 0.9188 - val_iou: 0.8511
# Epoch 74/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0778 - dice_coef: 0.9253 - iou: 0.8622 - val_loss: 0.0862 - val_dice_coef: 0.9177 - val_iou: 0.8499
# Epoch 75/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0761 - dice_coef: 0.9268 - iou: 0.8659 - val_loss: 0.0832 - val_dice_coef: 0.9203 - val_iou: 0.8531
# Epoch 76/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0751 - dice_coef: 0.9278 - iou: 0.8669 - val_loss: 0.0874 - val_dice_coef: 0.9165 - val_iou: 0.8471
# Epoch 77/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0726 - dice_coef: 0.9301 - iou: 0.8716 - val_loss: 0.1111 - val_dice_coef: 0.8954 - val_iou: 0.8133
# Epoch 78/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0795 - dice_coef: 0.9238 - iou: 0.8611 - val_loss: 0.1185 - val_dice_coef: 0.8886 - val_iou: 0.8011
# Epoch 79/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0747 - dice_coef: 0.9282 - iou: 0.8676 - val_loss: 0.1178 - val_dice_coef: 0.8893 - val_iou: 0.8019
# Epoch 80/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0668 - dice_coef: 0.9355 - iou: 0.8808 - val_loss: 0.0734 - val_dice_coef: 0.9296 - val_iou: 0.8712
# Epoch 81/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0846 - dice_coef: 0.9192 - iou: 0.8528 - val_loss: 0.1130 - val_dice_coef: 0.8935 - val_iou: 0.8088
# Epoch 82/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0782 - dice_coef: 0.9250 - iou: 0.8625 - val_loss: 0.0904 - val_dice_coef: 0.9137 - val_iou: 0.8423
# Epoch 83/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0667 - dice_coef: 0.9356 - iou: 0.8808 - val_loss: 0.1012 - val_dice_coef: 0.9045 - val_iou: 0.8282
# Epoch 84/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0714 - dice_coef: 0.9313 - iou: 0.8740 - val_loss: 0.0790 - val_dice_coef: 0.9242 - val_iou: 0.8606
# Epoch 85/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0687 - dice_coef: 0.9337 - iou: 0.8776 - val_loss: 0.0988 - val_dice_coef: 0.9061 - val_iou: 0.8287
# Epoch 86/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0609 - dice_coef: 0.9410 - iou: 0.8904 - val_loss: 0.0822 - val_dice_coef: 0.9213 - val_iou: 0.8559
# Epoch 87/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0653 - dice_coef: 0.9369 - iou: 0.8835 - val_loss: 0.0796 - val_dice_coef: 0.9238 - val_iou: 0.8605
# Epoch 88/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0727 - dice_coef: 0.9302 - iou: 0.8714 - val_loss: 0.0742 - val_dice_coef: 0.9287 - val_iou: 0.8684
# Epoch 89/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0720 - dice_coef: 0.9308 - iou: 0.8722 - val_loss: 0.0758 - val_dice_coef: 0.9274 - val_iou: 0.8677
# Epoch 90/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0691 - dice_coef: 0.9334 - iou: 0.8774 - val_loss: 0.0711 - val_dice_coef: 0.9318 - val_iou: 0.8752
# Epoch 91/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0722 - dice_coef: 0.9306 - iou: 0.8719 - val_loss: 0.0830 - val_dice_coef: 0.9203 - val_iou: 0.8529
# Epoch 92/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0833 - dice_coef: 0.9205 - iou: 0.8557 - val_loss: 0.0884 - val_dice_coef: 0.9155 - val_iou: 0.8454
# Epoch 93/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0786 - dice_coef: 0.9247 - iou: 0.8619 - val_loss: 0.0980 - val_dice_coef: 0.9069 - val_iou: 0.8297
# Epoch 94/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0703 - dice_coef: 0.9323 - iou: 0.8747 - val_loss: 0.0967 - val_dice_coef: 0.9081 - val_iou: 0.8327
# Epoch 95/300
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0625 - dice_coef: 0.9395 - iou: 0.8879 - val_loss: 0.0726 - val_dice_coef: 0.9303 - val_iou: 0.8720
# Epoch 96/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0656 - dice_coef: 0.9366 - iou: 0.8826 - val_loss: 0.0622 - val_dice_coef: 0.9399 - val_iou: 0.8882
# Epoch 97/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0675 - dice_coef: 0.9349 - iou: 0.8797 - val_loss: 0.0716 - val_dice_coef: 0.9310 - val_iou: 0.8718
# Epoch 98/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0680 - dice_coef: 0.9345 - iou: 0.8784 - val_loss: 0.0637 - val_dice_coef: 0.9383 - val_iou: 0.8854
# Epoch 99/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0649 - dice_coef: 0.9373 - iou: 0.8839 - val_loss: 0.0830 - val_dice_coef: 0.9205 - val_iou: 0.8538
# Epoch 100/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0634 - dice_coef: 0.9387 - iou: 0.8860 - val_loss: 0.0657 - val_dice_coef: 0.9365 - val_iou: 0.8817
# Epoch 101/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0616 - dice_coef: 0.9404 - iou: 0.8892 - val_loss: 0.0765 - val_dice_coef: 0.9268 - val_iou: 0.8662
# Epoch 102/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0604 - dice_coef: 0.9414 - iou: 0.8918 - val_loss: 0.0943 - val_dice_coef: 0.9102 - val_iou: 0.8357
# Epoch 103/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0559 - dice_coef: 0.9457 - iou: 0.8985 - val_loss: 0.0878 - val_dice_coef: 0.9165 - val_iou: 0.8482
# Epoch 104/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0604 - dice_coef: 0.9415 - iou: 0.8907 - val_loss: 0.0729 - val_dice_coef: 0.9299 - val_iou: 0.8699
# Epoch 105/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0663 - dice_coef: 0.9359 - iou: 0.8811 - val_loss: 0.1080 - val_dice_coef: 0.8984 - val_iou: 0.8183
# Epoch 106/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0603 - dice_coef: 0.9416 - iou: 0.8915 - val_loss: 0.0770 - val_dice_coef: 0.9265 - val_iou: 0.8654
# Epoch 107/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0572 - dice_coef: 0.9444 - iou: 0.8974 - val_loss: 0.1005 - val_dice_coef: 0.9048 - val_iou: 0.8279
# Epoch 108/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0606 - dice_coef: 0.9414 - iou: 0.8913 - val_loss: 0.0785 - val_dice_coef: 0.9248 - val_iou: 0.8620
# Epoch 109/300
# 20/20 [==============================] - 1s 40ms/step - loss: 0.0555 - dice_coef: 0.9461 - iou: 0.8993 - val_loss: 0.0586 - val_dice_coef: 0.9431 - val_iou: 0.8928
# Epoch 110/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0596 - dice_coef: 0.9422 - iou: 0.8933 - val_loss: 0.0786 - val_dice_coef: 0.9245 - val_iou: 0.8599
# Epoch 111/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0587 - dice_coef: 0.9432 - iou: 0.8942 - val_loss: 0.0782 - val_dice_coef: 0.9249 - val_iou: 0.8612
# Epoch 112/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0614 - dice_coef: 0.9407 - iou: 0.8898 - val_loss: 0.0740 - val_dice_coef: 0.9287 - val_iou: 0.8672
# Epoch 113/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0591 - dice_coef: 0.9427 - iou: 0.8941 - val_loss: 0.0881 - val_dice_coef: 0.9158 - val_iou: 0.8458
# Epoch 114/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0586 - dice_coef: 0.9432 - iou: 0.8939 - val_loss: 0.1035 - val_dice_coef: 0.9018 - val_iou: 0.8222
# Epoch 115/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0565 - dice_coef: 0.9451 - iou: 0.8979 - val_loss: 0.0947 - val_dice_coef: 0.9099 - val_iou: 0.8354
# Epoch 116/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0636 - dice_coef: 0.9386 - iou: 0.8866 - val_loss: 0.0703 - val_dice_coef: 0.9323 - val_iou: 0.8743
# Epoch 117/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0554 - dice_coef: 0.9462 - iou: 0.9000 - val_loss: 0.0812 - val_dice_coef: 0.9231 - val_iou: 0.8595
# Epoch 118/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0549 - dice_coef: 0.9466 - iou: 0.9003 - val_loss: 0.0840 - val_dice_coef: 0.9197 - val_iou: 0.8531
# Epoch 119/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0572 - dice_coef: 0.9445 - iou: 0.8966 - val_loss: 0.1065 - val_dice_coef: 0.8991 - val_iou: 0.8169
# Epoch 120/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0572 - dice_coef: 0.9446 - iou: 0.8969 - val_loss: 0.0718 - val_dice_coef: 0.9309 - val_iou: 0.8716
# Epoch 121/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0546 - dice_coef: 0.9469 - iou: 0.9011 - val_loss: 0.0765 - val_dice_coef: 0.9265 - val_iou: 0.8641
# Epoch 122/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0550 - dice_coef: 0.9466 - iou: 0.9000 - val_loss: 0.1045 - val_dice_coef: 0.9010 - val_iou: 0.8217
# Epoch 123/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0800 - dice_coef: 0.9236 - iou: 0.8610 - val_loss: 0.0937 - val_dice_coef: 0.9118 - val_iou: 0.8423
# Epoch 124/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0886 - dice_coef: 0.9155 - iou: 0.8460 - val_loss: 0.0777 - val_dice_coef: 0.9255 - val_iou: 0.8632
# Epoch 125/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0785 - dice_coef: 0.9248 - iou: 0.8621 - val_loss: 0.0658 - val_dice_coef: 0.9364 - val_iou: 0.8815
# Epoch 126/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0591 - dice_coef: 0.9427 - iou: 0.8934 - val_loss: 0.0807 - val_dice_coef: 0.9226 - val_iou: 0.8569
# Epoch 127/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0586 - dice_coef: 0.9433 - iou: 0.8945 - val_loss: 0.0782 - val_dice_coef: 0.9249 - val_iou: 0.8618
# Epoch 128/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0548 - dice_coef: 0.9467 - iou: 0.9004 - val_loss: 0.1239 - val_dice_coef: 0.8836 - val_iou: 0.7935
# Epoch 129/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0587 - dice_coef: 0.9431 - iou: 0.8936 - val_loss: 0.1028 - val_dice_coef: 0.9028 - val_iou: 0.8254
# Epoch 130/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0535 - dice_coef: 0.9480 - iou: 0.9031 - val_loss: 0.0786 - val_dice_coef: 0.9248 - val_iou: 0.8636
# Epoch 131/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0563 - dice_coef: 0.9453 - iou: 0.8986 - val_loss: 0.0789 - val_dice_coef: 0.9246 - val_iou: 0.8615
# Epoch 132/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0605 - dice_coef: 0.9413 - iou: 0.8912 - val_loss: 0.0726 - val_dice_coef: 0.9302 - val_iou: 0.8722
# Epoch 133/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0561 - dice_coef: 0.9456 - iou: 0.8985 - val_loss: 0.1298 - val_dice_coef: 0.8784 - val_iou: 0.7843
# Epoch 134/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0565 - dice_coef: 0.9452 - iou: 0.8971 - val_loss: 0.0758 - val_dice_coef: 0.9271 - val_iou: 0.8638
# Epoch 135/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0518 - dice_coef: 0.9495 - iou: 0.9058 - val_loss: 0.0989 - val_dice_coef: 0.9062 - val_iou: 0.8313
# Epoch 136/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0500 - dice_coef: 0.9513 - iou: 0.9084 - val_loss: 0.0763 - val_dice_coef: 0.9266 - val_iou: 0.8632
# Epoch 137/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0497 - dice_coef: 0.9515 - iou: 0.9092 - val_loss: 0.0802 - val_dice_coef: 0.9232 - val_iou: 0.8570
# Epoch 138/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0527 - dice_coef: 0.9487 - iou: 0.9046 - val_loss: 0.0716 - val_dice_coef: 0.9310 - val_iou: 0.8720
# Epoch 139/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0510 - dice_coef: 0.9503 - iou: 0.9072 - val_loss: 0.0760 - val_dice_coef: 0.9270 - val_iou: 0.8650
# Epoch 140/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0506 - dice_coef: 0.9507 - iou: 0.9079 - val_loss: 0.0865 - val_dice_coef: 0.9175 - val_iou: 0.8492
# Epoch 141/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0568 - dice_coef: 0.9449 - iou: 0.8971 - val_loss: 0.0889 - val_dice_coef: 0.9152 - val_iou: 0.8449
# Epoch 142/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0522 - dice_coef: 0.9493 - iou: 0.9057 - val_loss: 0.0821 - val_dice_coef: 0.9213 - val_iou: 0.8555
# Epoch 143/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0484 - dice_coef: 0.9528 - iou: 0.9118 - val_loss: 0.0808 - val_dice_coef: 0.9225 - val_iou: 0.8571
# Epoch 144/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0514 - dice_coef: 0.9500 - iou: 0.9069 - val_loss: 0.0677 - val_dice_coef: 0.9346 - val_iou: 0.8793
# Epoch 145/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0518 - dice_coef: 0.9496 - iou: 0.9053 - val_loss: 0.0867 - val_dice_coef: 0.9171 - val_iou: 0.8471
# Epoch 146/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0566 - dice_coef: 0.9451 - iou: 0.8976 - val_loss: 0.0852 - val_dice_coef: 0.9187 - val_iou: 0.8516
# Epoch 147/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0458 - dice_coef: 0.9553 - iou: 0.9158 - val_loss: 0.1009 - val_dice_coef: 0.9043 - val_iou: 0.8259
# Epoch 148/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0502 - dice_coef: 0.9511 - iou: 0.9084 - val_loss: 0.0738 - val_dice_coef: 0.9290 - val_iou: 0.8695
# Epoch 149/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0504 - dice_coef: 0.9510 - iou: 0.9080 - val_loss: 0.0929 - val_dice_coef: 0.9115 - val_iou: 0.8391
# Epoch 150/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0537 - dice_coef: 0.9478 - iou: 0.9021 - val_loss: 0.0930 - val_dice_coef: 0.9118 - val_iou: 0.8394
# Epoch 151/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0516 - dice_coef: 0.9498 - iou: 0.9063 - val_loss: 0.0632 - val_dice_coef: 0.9390 - val_iou: 0.8862
# Epoch 152/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0567 - dice_coef: 0.9450 - iou: 0.8975 - val_loss: 0.0782 - val_dice_coef: 0.9252 - val_iou: 0.8623
# Epoch 153/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0511 - dice_coef: 0.9503 - iou: 0.9065 - val_loss: 0.0716 - val_dice_coef: 0.9310 - val_iou: 0.8716
# Epoch 154/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0502 - dice_coef: 0.9511 - iou: 0.9089 - val_loss: 0.0816 - val_dice_coef: 0.9218 - val_iou: 0.8558
# Epoch 155/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0491 - dice_coef: 0.9522 - iou: 0.9104 - val_loss: 0.0703 - val_dice_coef: 0.9322 - val_iou: 0.8732
# Epoch 156/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0480 - dice_coef: 0.9532 - iou: 0.9118 - val_loss: 0.1049 - val_dice_coef: 0.9012 - val_iou: 0.8218
# Epoch 157/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0519 - dice_coef: 0.9495 - iou: 0.9050 - val_loss: 0.1058 - val_dice_coef: 0.8999 - val_iou: 0.8190
# Epoch 158/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0487 - dice_coef: 0.9526 - iou: 0.9109 - val_loss: 0.0761 - val_dice_coef: 0.9267 - val_iou: 0.8644
# Epoch 159/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0522 - dice_coef: 0.9493 - iou: 0.9052 - val_loss: 0.1227 - val_dice_coef: 0.8849 - val_iou: 0.7933
# Epoch 160/300
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0535 - dice_coef: 0.9480 - iou: 0.9024 - val_loss: 0.0769 - val_dice_coef: 0.9265 - val_iou: 0.8647
# Epoch 161/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0585 - dice_coef: 0.9435 - iou: 0.8956 - val_loss: 0.0653 - val_dice_coef: 0.9370 - val_iou: 0.8830
# Epoch 162/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0567 - dice_coef: 0.9450 - iou: 0.8976 - val_loss: 0.0755 - val_dice_coef: 0.9276 - val_iou: 0.8665
# Epoch 163/300
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0486 - dice_coef: 0.9526 - iou: 0.9112 - val_loss: 0.0815 - val_dice_coef: 0.9218 - val_iou: 0.8546
# Epoch 164/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0488 - dice_coef: 0.9525 - iou: 0.9109 - val_loss: 0.0527 - val_dice_coef: 0.9488 - val_iou: 0.9036
# Epoch 165/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0581 - dice_coef: 0.9437 - iou: 0.8953 - val_loss: 0.0700 - val_dice_coef: 0.9326 - val_iou: 0.8755
# Epoch 166/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0510 - dice_coef: 0.9504 - iou: 0.9071 - val_loss: 0.0675 - val_dice_coef: 0.9351 - val_iou: 0.8811
# Epoch 167/300
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0465 - dice_coef: 0.9546 - iou: 0.9151 - val_loss: 0.0948 - val_dice_coef: 0.9098 - val_iou: 0.8355
# Epoch 168/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0514 - dice_coef: 0.9500 - iou: 0.9063 - val_loss: 0.0877 - val_dice_coef: 0.9163 - val_iou: 0.8465
# Epoch 169/300
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0461 - dice_coef: 0.9550 - iou: 0.9157 - val_loss: 0.0926 - val_dice_coef: 0.9120 - val_iou: 0.8397
# Epoch 170/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0440 - dice_coef: 0.9570 - iou: 0.9194 - val_loss: 0.0878 - val_dice_coef: 0.9160 - val_iou: 0.8457
# Epoch 171/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0491 - dice_coef: 0.9522 - iou: 0.9103 - val_loss: 0.0944 - val_dice_coef: 0.9103 - val_iou: 0.8373
# Epoch 172/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0463 - dice_coef: 0.9548 - iou: 0.9151 - val_loss: 0.1250 - val_dice_coef: 0.8830 - val_iou: 0.7929
# Epoch 173/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0505 - dice_coef: 0.9509 - iou: 0.9081 - val_loss: 0.0960 - val_dice_coef: 0.9086 - val_iou: 0.8321
# Epoch 174/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0644 - dice_coef: 0.9381 - iou: 0.8861 - val_loss: 0.0964 - val_dice_coef: 0.9083 - val_iou: 0.8334
# Epoch 175/300
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0534 - dice_coef: 0.9482 - iou: 0.9032 - val_loss: 0.0915 - val_dice_coef: 0.9132 - val_iou: 0.8430
# Epoch 176/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0567 - dice_coef: 0.9451 - iou: 0.8974 - val_loss: 0.0682 - val_dice_coef: 0.9343 - val_iou: 0.8779
# Epoch 177/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0541 - dice_coef: 0.9474 - iou: 0.9016 - val_loss: 0.0614 - val_dice_coef: 0.9406 - val_iou: 0.8898
# Epoch 178/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0505 - dice_coef: 0.9508 - iou: 0.9076 - val_loss: 0.0885 - val_dice_coef: 0.9154 - val_iou: 0.8437
# Epoch 179/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0489 - dice_coef: 0.9524 - iou: 0.9117 - val_loss: 0.0776 - val_dice_coef: 0.9254 - val_iou: 0.8620
# Epoch 180/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0478 - dice_coef: 0.9534 - iou: 0.9120 - val_loss: 0.0761 - val_dice_coef: 0.9268 - val_iou: 0.8649
# Epoch 181/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0461 - dice_coef: 0.9550 - iou: 0.9152 - val_loss: 0.0862 - val_dice_coef: 0.9176 - val_iou: 0.8473
# Epoch 182/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0482 - dice_coef: 0.9530 - iou: 0.9120 - val_loss: 0.0867 - val_dice_coef: 0.9172 - val_iou: 0.8483
# Epoch 183/300
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0507 - dice_coef: 0.9507 - iou: 0.9072 - val_loss: 0.0761 - val_dice_coef: 0.9269 - val_iou: 0.8641
# Epoch 184/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0458 - dice_coef: 0.9554 - iou: 0.9161 - val_loss: 0.0838 - val_dice_coef: 0.9198 - val_iou: 0.8523
# Epoch 185/300
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0467 - dice_coef: 0.9544 - iou: 0.9139 - val_loss: 0.0972 - val_dice_coef: 0.9074 - val_iou: 0.8306
# Epoch 186/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0452 - dice_coef: 0.9558 - iou: 0.9168 - val_loss: 0.0844 - val_dice_coef: 0.9193 - val_iou: 0.8512
# Epoch 187/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0453 - dice_coef: 0.9558 - iou: 0.9168 - val_loss: 0.0930 - val_dice_coef: 0.9113 - val_iou: 0.8377
# Epoch 188/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0443 - dice_coef: 0.9568 - iou: 0.9184 - val_loss: 0.0922 - val_dice_coef: 0.9123 - val_iou: 0.8395
# Epoch 189/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0443 - dice_coef: 0.9567 - iou: 0.9181 - val_loss: 0.0838 - val_dice_coef: 0.9197 - val_iou: 0.8523
# Epoch 190/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0425 - dice_coef: 0.9584 - iou: 0.9215 - val_loss: 0.0730 - val_dice_coef: 0.9297 - val_iou: 0.8699
# Epoch 191/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0447 - dice_coef: 0.9564 - iou: 0.9177 - val_loss: 0.0958 - val_dice_coef: 0.9091 - val_iou: 0.8351
# Epoch 192/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0402 - dice_coef: 0.9606 - iou: 0.9256 - val_loss: 0.0992 - val_dice_coef: 0.9062 - val_iou: 0.8303
# Epoch 193/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0414 - dice_coef: 0.9595 - iou: 0.9233 - val_loss: 0.1118 - val_dice_coef: 0.8945 - val_iou: 0.8106
# Epoch 194/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0442 - dice_coef: 0.9569 - iou: 0.9187 - val_loss: 0.1145 - val_dice_coef: 0.8921 - val_iou: 0.8056
# Epoch 195/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0416 - dice_coef: 0.9593 - iou: 0.9229 - val_loss: 0.0840 - val_dice_coef: 0.9197 - val_iou: 0.8516
# Epoch 196/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0427 - dice_coef: 0.9583 - iou: 0.9212 - val_loss: 0.0840 - val_dice_coef: 0.9197 - val_iou: 0.8522
# Epoch 197/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0494 - dice_coef: 0.9519 - iou: 0.9093 - val_loss: 0.0915 - val_dice_coef: 0.9126 - val_iou: 0.8397
# Epoch 198/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0481 - dice_coef: 0.9532 - iou: 0.9120 - val_loss: 0.0775 - val_dice_coef: 0.9259 - val_iou: 0.8645
# Epoch 199/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0452 - dice_coef: 0.9559 - iou: 0.9163 - val_loss: 0.0577 - val_dice_coef: 0.9441 - val_iou: 0.8948
# Epoch 200/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0488 - dice_coef: 0.9524 - iou: 0.9099 - val_loss: 0.0749 - val_dice_coef: 0.9280 - val_iou: 0.8652
# Epoch 201/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0446 - dice_coef: 0.9565 - iou: 0.9180 - val_loss: 0.0869 - val_dice_coef: 0.9171 - val_iou: 0.8482
# Epoch 202/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0405 - dice_coef: 0.9603 - iou: 0.9254 - val_loss: 0.0976 - val_dice_coef: 0.9076 - val_iou: 0.8325
# Epoch 203/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0457 - dice_coef: 0.9554 - iou: 0.9156 - val_loss: 0.0561 - val_dice_coef: 0.9455 - val_iou: 0.8970
# Epoch 204/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0440 - dice_coef: 0.9571 - iou: 0.9191 - val_loss: 0.0791 - val_dice_coef: 0.9241 - val_iou: 0.8587
# Epoch 205/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0398 - dice_coef: 0.9610 - iou: 0.9260 - val_loss: 0.0897 - val_dice_coef: 0.9143 - val_iou: 0.8420
# Epoch 206/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0400 - dice_coef: 0.9608 - iou: 0.9253 - val_loss: 0.0721 - val_dice_coef: 0.9305 - val_iou: 0.8701
# Epoch 207/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0412 - dice_coef: 0.9597 - iou: 0.9237 - val_loss: 0.0962 - val_dice_coef: 0.9085 - val_iou: 0.8334
# Epoch 208/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0423 - dice_coef: 0.9586 - iou: 0.9218 - val_loss: 0.0934 - val_dice_coef: 0.9110 - val_iou: 0.8367
# Epoch 209/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0431 - dice_coef: 0.9578 - iou: 0.9207 - val_loss: 0.1142 - val_dice_coef: 0.8923 - val_iou: 0.8063
# Epoch 210/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0440 - dice_coef: 0.9570 - iou: 0.9186 - val_loss: 0.0928 - val_dice_coef: 0.9115 - val_iou: 0.8371
# Epoch 211/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0418 - dice_coef: 0.9591 - iou: 0.9228 - val_loss: 0.0713 - val_dice_coef: 0.9313 - val_iou: 0.8723
# Epoch 212/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0443 - dice_coef: 0.9568 - iou: 0.9182 - val_loss: 0.0790 - val_dice_coef: 0.9242 - val_iou: 0.8603
# Epoch 213/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0473 - dice_coef: 0.9539 - iou: 0.9132 - val_loss: 0.0715 - val_dice_coef: 0.9312 - val_iou: 0.8721
# Epoch 214/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0424 - dice_coef: 0.9586 - iou: 0.9217 - val_loss: 0.0934 - val_dice_coef: 0.9111 - val_iou: 0.8381
# Epoch 215/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0428 - dice_coef: 0.9582 - iou: 0.9209 - val_loss: 0.0639 - val_dice_coef: 0.9383 - val_iou: 0.8850
# Epoch 216/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0410 - dice_coef: 0.9599 - iou: 0.9240 - val_loss: 0.0817 - val_dice_coef: 0.9216 - val_iou: 0.8548
# Epoch 217/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0437 - dice_coef: 0.9573 - iou: 0.9193 - val_loss: 0.0730 - val_dice_coef: 0.9298 - val_iou: 0.8690
# Epoch 218/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0438 - dice_coef: 0.9572 - iou: 0.9190 - val_loss: 0.0801 - val_dice_coef: 0.9230 - val_iou: 0.8565
# Epoch 219/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0450 - dice_coef: 0.9561 - iou: 0.9171 - val_loss: 0.0594 - val_dice_coef: 0.9424 - val_iou: 0.8923
# Epoch 220/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0470 - dice_coef: 0.9541 - iou: 0.9133 - val_loss: 0.0616 - val_dice_coef: 0.9403 - val_iou: 0.8878
# Epoch 221/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0466 - dice_coef: 0.9545 - iou: 0.9141 - val_loss: 0.0734 - val_dice_coef: 0.9294 - val_iou: 0.8694
# Epoch 222/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0441 - dice_coef: 0.9570 - iou: 0.9190 - val_loss: 0.0752 - val_dice_coef: 0.9276 - val_iou: 0.8660
# Epoch 223/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0427 - dice_coef: 0.9582 - iou: 0.9214 - val_loss: 0.0901 - val_dice_coef: 0.9140 - val_iou: 0.8428
# Epoch 224/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0408 - dice_coef: 0.9601 - iou: 0.9243 - val_loss: 0.0842 - val_dice_coef: 0.9194 - val_iou: 0.8525
# Epoch 225/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0450 - dice_coef: 0.9561 - iou: 0.9171 - val_loss: 0.0896 - val_dice_coef: 0.9145 - val_iou: 0.8434
# Epoch 226/300
# 20/20 [==============================] - 1s 35ms/step - loss: 0.0407 - dice_coef: 0.9602 - iou: 0.9249 - val_loss: 0.0846 - val_dice_coef: 0.9190 - val_iou: 0.8498
# Epoch 227/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0411 - dice_coef: 0.9598 - iou: 0.9241 - val_loss: 0.0860 - val_dice_coef: 0.9181 - val_iou: 0.8502
# Epoch 228/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0428 - dice_coef: 0.9582 - iou: 0.9210 - val_loss: 0.0869 - val_dice_coef: 0.9171 - val_iou: 0.8473
# Epoch 229/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0393 - dice_coef: 0.9615 - iou: 0.9270 - val_loss: 0.0710 - val_dice_coef: 0.9316 - val_iou: 0.8736
# Epoch 230/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0417 - dice_coef: 0.9593 - iou: 0.9232 - val_loss: 0.0964 - val_dice_coef: 0.9081 - val_iou: 0.8313
# Epoch 231/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0434 - dice_coef: 0.9576 - iou: 0.9200 - val_loss: 0.0997 - val_dice_coef: 0.9054 - val_iou: 0.8286
# Epoch 232/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0432 - dice_coef: 0.9579 - iou: 0.9207 - val_loss: 0.0892 - val_dice_coef: 0.9149 - val_iou: 0.8449
# Epoch 233/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0422 - dice_coef: 0.9587 - iou: 0.9217 - val_loss: 0.0786 - val_dice_coef: 0.9245 - val_iou: 0.8601
# Epoch 234/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0426 - dice_coef: 0.9584 - iou: 0.9217 - val_loss: 0.1017 - val_dice_coef: 0.9035 - val_iou: 0.8247
# Epoch 235/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0397 - dice_coef: 0.9612 - iou: 0.9264 - val_loss: 0.0685 - val_dice_coef: 0.9342 - val_iou: 0.8786
# Epoch 236/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0409 - dice_coef: 0.9600 - iou: 0.9240 - val_loss: 0.0858 - val_dice_coef: 0.9183 - val_iou: 0.8505
# Epoch 237/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0425 - dice_coef: 0.9584 - iou: 0.9211 - val_loss: 0.0849 - val_dice_coef: 0.9188 - val_iou: 0.8501
# Epoch 238/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0404 - dice_coef: 0.9604 - iou: 0.9250 - val_loss: 0.0730 - val_dice_coef: 0.9297 - val_iou: 0.8686
# Epoch 239/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0386 - dice_coef: 0.9622 - iou: 0.9283 - val_loss: 0.0621 - val_dice_coef: 0.9399 - val_iou: 0.8882
# Epoch 240/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0390 - dice_coef: 0.9617 - iou: 0.9275 - val_loss: 0.0885 - val_dice_coef: 0.9159 - val_iou: 0.8472
# Epoch 241/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0383 - dice_coef: 0.9625 - iou: 0.9291 - val_loss: 0.0812 - val_dice_coef: 0.9221 - val_iou: 0.8565
# Epoch 242/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0430 - dice_coef: 0.9580 - iou: 0.9203 - val_loss: 0.0843 - val_dice_coef: 0.9196 - val_iou: 0.8527
# Epoch 243/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0404 - dice_coef: 0.9604 - iou: 0.9250 - val_loss: 0.0831 - val_dice_coef: 0.9203 - val_iou: 0.8526
# Epoch 244/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0431 - dice_coef: 0.9579 - iou: 0.9206 - val_loss: 0.0998 - val_dice_coef: 0.9051 - val_iou: 0.8281
# Epoch 245/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0402 - dice_coef: 0.9607 - iou: 0.9255 - val_loss: 0.0868 - val_dice_coef: 0.9173 - val_iou: 0.8473
# Epoch 246/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0381 - dice_coef: 0.9626 - iou: 0.9289 - val_loss: 0.1068 - val_dice_coef: 0.8994 - val_iou: 0.8186
# Epoch 247/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0404 - dice_coef: 0.9605 - iou: 0.9248 - val_loss: 0.0781 - val_dice_coef: 0.9250 - val_iou: 0.8619
# Epoch 248/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0370 - dice_coef: 0.9638 - iou: 0.9312 - val_loss: 0.0776 - val_dice_coef: 0.9255 - val_iou: 0.8611
# Epoch 249/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0362 - dice_coef: 0.9645 - iou: 0.9322 - val_loss: 0.0668 - val_dice_coef: 0.9354 - val_iou: 0.8787
# Epoch 250/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0428 - dice_coef: 0.9582 - iou: 0.9206 - val_loss: 0.0726 - val_dice_coef: 0.9302 - val_iou: 0.8709
# Epoch 251/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0369 - dice_coef: 0.9638 - iou: 0.9311 - val_loss: 0.0716 - val_dice_coef: 0.9312 - val_iou: 0.8736
# Epoch 252/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0392 - dice_coef: 0.9616 - iou: 0.9271 - val_loss: 0.1014 - val_dice_coef: 0.9039 - val_iou: 0.8250
# Epoch 253/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0403 - dice_coef: 0.9606 - iou: 0.9256 - val_loss: 0.0838 - val_dice_coef: 0.9198 - val_iou: 0.8513
# Epoch 254/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0405 - dice_coef: 0.9603 - iou: 0.9246 - val_loss: 0.0906 - val_dice_coef: 0.9136 - val_iou: 0.8409
# Epoch 255/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0387 - dice_coef: 0.9621 - iou: 0.9279 - val_loss: 0.0619 - val_dice_coef: 0.9401 - val_iou: 0.8882
# Epoch 256/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0373 - dice_coef: 0.9635 - iou: 0.9306 - val_loss: 0.0741 - val_dice_coef: 0.9287 - val_iou: 0.8678
# Epoch 257/300
# 20/20 [==============================] - 1s 38ms/step - loss: 0.0404 - dice_coef: 0.9604 - iou: 0.9250 - val_loss: 0.0635 - val_dice_coef: 0.9386 - val_iou: 0.8851
# Epoch 258/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0396 - dice_coef: 0.9612 - iou: 0.9264 - val_loss: 0.1062 - val_dice_coef: 0.8999 - val_iou: 0.8194
# Epoch 259/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0388 - dice_coef: 0.9620 - iou: 0.9279 - val_loss: 0.0882 - val_dice_coef: 0.9159 - val_iou: 0.8455
# Epoch 260/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0344 - dice_coef: 0.9662 - iou: 0.9359 - val_loss: 0.0689 - val_dice_coef: 0.9338 - val_iou: 0.8771
# Epoch 261/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0393 - dice_coef: 0.9615 - iou: 0.9274 - val_loss: 0.0691 - val_dice_coef: 0.9333 - val_iou: 0.8762
# Epoch 262/300
# 20/20 [==============================] - 1s 37ms/step - loss: 0.0382 - dice_coef: 0.9626 - iou: 0.9289 - val_loss: 0.0804 - val_dice_coef: 0.9228 - val_iou: 0.8576
# Epoch 263/300
# 20/20 [==============================] - 1s 36ms/step - loss: 0.0373 - dice_coef: 0.9634 - iou: 0.9305 - val_loss: 0.0982 - val_dice_coef: 0.9068 - val_iou: 0.8301
# Epoch 264/300
# 20/20 [==============================] - 1s 39ms/step - loss: 0.0388 - dice_coef: 0.9620 - iou: 0.9281 - val_loss: 0.0816 - val_dice_coef: 0.9218 - val_iou: 0.8554

# %%
best_epoch = np.argmin(history.history["val_loss"])
best_epoch2 = np.argmin(history.history['loss'])
print(history.history["loss"][best_epoch2])
print("Best Validation Loss: ", history.history["val_loss"][best_epoch])
print("Best Dice Coffecient (F1): ", history.history["val_dice_coef"][best_epoch])
print("Best IoU (Jaccard): ", history.history["val_iou"][best_epoch])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 best_epoch = np.argmin(history.history["val_loss"])
#       2 best_epoch2 = np.argmin(history.history['loss'])
#       3 print(history.history["loss"][best_epoch2])
#
# NameError: name 'history' is not defined

# %%
t_loss = history.history['loss']
val_loss = history.history['val_loss']
acc=history.history['dice_coef']
epochs = range(1, len(t_loss) + 1)
plt.figure(figsize=(8, 8))
plt.plot(epochs, t_loss, 'orange', label='Train Loss')
plt.plot(epochs, val_loss, 'y', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Log Dice Loss')
# plt.grid()
plt.legend()

# %%
loss = history.history['loss']
acc=history.history['dice_coef']
val_acc=history.history['val_dice_coef']
epochs = range(1, len(acc) + 1)
plt.figure(figsize=(8, 8))
plt.plot(epochs, acc, 'c', label='Train')
plt.plot(epochs, val_acc, 'b', label='Validation')
plt.title('Training and Validation Dice')
plt.xlabel('Epochs')
plt.ylabel('Dice Coef')
# plt.grid()
plt.legend()

# %%
from skimage.morphology import dilation
from skimage.feature import canny
from skimage import color

# %%
for image , mask, file_name in zip(X_test[: 10], Y_test[:10], name_test[:10]):

    x_test = image.copy()
    x_test = tf.image.resize(x_test, (128, 128))/122.5 - 1.0

    mask = (mask[:, :, 0] > 225.5) + 0.0
    

    pred = (model.predict(tf.expand_dims(x_test, axis=0), verbose=0)[0] > 0.5).astype(float)
    pred = cv2.resize(pred, (256, 256))

    fig = plt.figure(figsize=(10, 4))
    ax = fig.add_subplot(1, 3, 1)
    ax.set_title('Predicted')
    edgesp = canny(pred)
    edgesp = 1.0-dilation(edgesp)
    edgesp = color.gray2rgb(1.0*edgesp)
    ax.imshow((image*edgesp).astype(int)[:, :, ::-1])


    ax = fig.add_subplot(1, 3, 2)
    ax.set_title('Correct')
    edgesc = canny(mask)
    edgesc = 1.0-dilation(edgesc)
    edgesc = color.gray2rgb(1.0*edgesc)
    ax.imshow((image*edgesc).astype(int)[:, :, ::-1])

    ax = fig.add_subplot(1, 3, 3)
    ax.set_title('Image')
    ax.imshow(image[:, :, ::-1])

# %%
for image , mask, file_name in zip(X_test[: 10], Y_test[:10], name_test[:10]):

    x_test = image.copy()
    x_test = tf.image.resize(x_test, (128, 128))/122.5 - 1.0

    mask = (mask[:, :, 0] > 100) + 0.0
    

    pred = (model.predict(tf.expand_dims(x_test, axis=0), verbose=0)[0] > 0.5).astype(float)
    pred = cv2.resize(pred, (256, 256))

    fig = plt.figure(figsize=(10, 4))
    ax = fig.add_subplot(1, 3, 1)
    ax.set_title('Predicted')
#     edgesp = canny(pred)
#     edgesp = 1.0-dilation(edgesp)
#     edgesp = color.gray2rgb(1.0*edgesp)
    ax.imshow(pred)


    ax = fig.add_subplot(1, 3, 2)
    ax.set_title('Correct')
#     edgesc = canny(mask)
#     edgesc = 1.0-dilation(edgesc)
#     edgesc = color.gray2rgb(1.0*edgesc)
    ax.imshow(mask)

    ax = fig.add_subplot(1, 3, 3)
    ax.set_title('Image')
    ax.imshow(image[:, :, ::-1])
