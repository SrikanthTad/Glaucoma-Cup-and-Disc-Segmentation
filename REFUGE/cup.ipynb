# %%
import cv2
import tensorflow as tf
import numpy as np
import os
import matplotlib.pyplot as plt
# Out:
# 2023-04-24 18:14:52.610694: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-24 18:14:52.690913: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
IMAGE_DIR = "/data2/SrikanthData/ResearchWork2/tensorflow/Project/img_data/REFUGE/test/Images"

MASK_DIR = "/data2/SrikanthData/ResearchWork2/tensorflow/Project/img_data/REFUGE/test/test_cup"
BATCH_SIZE = 4

# %%
def double_conv_block(x, n_filters):
    # Conv2D then ReLU activation
    x = tf.keras.layers.Conv2D(
        n_filters,
        3,
        padding="same",
        activation="relu",
        kernel_initializer="he_normal"
    )(x)
    # Conv2D then ReLU activation
    x = tf.keras.layers.Conv2D(
        n_filters,
        3,
        padding="same",
        activation="relu",
        kernel_initializer="he_normal"
    )(x)
    return x

def downsample_block(x, n_filters):
    f = double_conv_block(x, n_filters)
    p = tf.keras.layers.MaxPool2D(2)(f)
    p = tf.keras.layers.Dropout(0.3)(p)
    return f, p

def upsample_block(x, conv_features, n_filters):
    # upsample
    x = tf.keras.layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
    # concatenate
    x = tf.keras.layers.concatenate([x, conv_features])
    # dropout
    x = tf.keras.layers.Dropout(0.3)(x)
    # Conv2D twice with ReLU activation
    x = double_conv_block(x, n_filters)
    return x

def create_unet():
    # inputs
    inputs = tf.keras.layers.Input(shape=(128,128,3))
    # encoder: contracting path - downsample
    # 1 - downsample
    f1, p1 = downsample_block(inputs, 32) # 64
    # 2 - downsample
    f2, p2 = downsample_block(p1, 64) # 128
    # 3 - downsample
    f3, p3 = downsample_block(p2, 128) # 256
    # 4 - downsample
    f4, p4 = downsample_block(p3, 256) # 512
    # 5 - bottleneck
    bottleneck = double_conv_block(p4, 256) # 1024

    # decoder: expanding path - upsample
    # 6 - upsample
    u6 = upsample_block(bottleneck, f4, 256) # 512
    # 7 - upsample
    u7 = upsample_block(u6, f3, 128) # 256
    # 8 - upsample
    u8 = upsample_block(u7, f2, 64) # 128
    # 9 - upsample
    u9 = upsample_block(u8, f1, 32)
    # outputs
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation = "sigmoid")(u9)
    # unet model with Keras Functional API
    unet_model = tf.keras.Model(inputs, outputs, name="U-Net")
    return unet_model

# %%
# load data
assert len(os.listdir(IMAGE_DIR)) == len(os.listdir(MASK_DIR)), "Different number of images and masks"
X, Y, file_names = [], [], []
for image_name in sorted(os.listdir(IMAGE_DIR)):
    mask_name = "image_" + image_name[2:5] + ".png"
    

    image = cv2.imread(os.path.join(IMAGE_DIR, image_name))
    image = cv2.resize(image, (256, 256))
    

    mask = cv2.imread(os.path.join(MASK_DIR, mask_name))
    mask = cv2.resize(mask, (256, 256))


    X.append(image)
    Y.append(mask)
    file_names.append(image_name)

# %%
def dice_coef(y_true, y_pred): # accuracy function 
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + 1e-6) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + 1e-6)
  
def dice_loss(y_true,y_pred): # loss function 
    return -dice_coef(y_true,y_pred)
  
def log_dice_loss(y_true, y_pred):
    return -tf.math.log(dice_coef(y_true, y_pred))



def iou(y_true, y_pred, threshold=0.5):                                                             
    y_true = tf.reshape(y_true, [-1])                                                               
    y_true = tf.cast(y_true, tf.float32)                                                            
    y_pred = tf.cast(y_pred > threshold, tf.float32)                                                
                                                                                                    
    y_pred = tf.reshape(y_pred, [-1])                                                               
                                                                                                    
                                                                                                    
    intersection = tf.reduce_sum(y_true*y_pred)                                                     
    union = tf.reduce_sum(tf.cast(y_true + y_pred > 0, tf.float32))                                 
                                                                                                    
    return intersection/union

# %%
def augmentation_fn(image, mask, training=True):
    """
    Augmentation for training set only. random cropy 50% of the time, random flip 50% of the time
    """
    # change brightness

    image = image.copy()
    mask = mask.copy()
    if training:
        image = tf.image.random_brightness(image, 0.1)
        image = tf.image.random_hue(image, 0.1)
    
        seed = np.random.randint(0, 1000, (2, ))
        if np.random.rand() < 0.5:
            random_size = np.random.randint(210, 256) # this is because the size of the image is 256 
        
            image = tf.image.stateless_random_crop(image, [random_size, random_size, 3], seed=seed)
            mask = tf.image.stateless_random_crop(mask, [random_size, random_size, 3], seed=seed)

        if np.random.rand() < 0.5:
            image = tf.image.stateless_random_flip_up_down(image, seed)
            mask = tf.image.stateless_random_flip_up_down(mask, seed)


    image = tf.image.resize(image, (128, 128))/122.5 - 1.0
    mask = tf.cast(tf.image.resize(mask, (128, 128)) > 122.5, float)[:, :, :1]
    
    return image, mask

# %%
# Split train and test
mask = list(range(len(X)))
np.random.seed(0)
np.random.shuffle(mask)
n_train = int(0.8*len(mask))
X_train = [X[i] for i in mask[:n_train]]
Y_train = [Y[i] for i in mask[:n_train]]
name_train = [file_names[i] for i in mask[:n_train]]

X_test = [X[i] for i in mask[n_train:]]
Y_test = [Y[i] for i in mask[n_train:]]
name_test = [file_names[i] for i in mask[n_train:]]

def data_generator(X, Y, batch_size=BATCH_SIZE, training=True):
    n_data = len(X)

    i = 0
    while True:
        if i + batch_size > n_data:
            i = 0
            mask = np.arange(n_data)
            np.random.shuffle(mask)

            X = [X[j] for j in mask]
            Y = [Y[j] for j in mask]
        
        mini_X = X[i: i + batch_size] 
        mini_Y = Y[i: i + batch_size]

        
        processed_data = [augmentation_fn(x, y, training) for x, y in zip(mini_X, mini_Y)]
        mini_X = [item[0] for item in processed_data]
        mini_Y = [item[1] for item in processed_data]


        mini_X = tf.concat([tf.expand_dims(_, axis=0) for _ in mini_X], axis=0)
        mini_Y = tf.concat([tf.expand_dims(_, axis=0) for _ in mini_Y], axis=0)

        i += batch_size
        yield mini_X, mini_Y

# %%
model = create_unet()

model.summary()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=log_dice_loss,
    metrics=[dice_coef, iou]
)

train_generator = data_generator(X_train, Y_train, training=True)
validation_generator = data_generator(X_test, Y_test, training=False)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)
history = model.fit(
    train_generator,
    epochs=300,
    validation_data=validation_generator,
    steps_per_epoch=len(X_train)//BATCH_SIZE,
    validation_steps=len(X_test)//BATCH_SIZE,
    callbacks=[early_stopping]
)
# Out:
# 2023-04-24 18:15:13.911793: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22288 MB memory:  -> device: 0, name: GeForce RTX 3090, pci bus id: 0000:1b:00.0, compute capability: 8.6
# 2023-04-24 18:15:13.916258: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 20509 MB memory:  -> device: 1, name: GeForce RTX 3090, pci bus id: 0000:3e:00.0, compute capability: 8.6
# 2023-04-24 18:15:13.919402: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 15314 MB memory:  -> device: 2, name: GeForce RTX 3090, pci bus id: 0000:89:00.0, compute capability: 8.6
# 2023-04-24 18:15:13.921343: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 22288 MB memory:  -> device: 3, name: GeForce RTX 3090, pci bus id: 0000:b2:00.0, compute capability: 8.6
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['conv2d_1[0][0]']
#
#  dropout (Dropout)              (None, 64, 64, 32)   0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 64)   18496       ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)  0           ['conv2d_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 64)   0           ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 128)  73856       ['dropout_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0          ['conv2d_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 128)  0           ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 256)  295168      ['dropout_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 256)  590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)   0           ['conv2d_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 8, 8, 256)    0           ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    590080      ['dropout_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 256)    590080      ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 256)  590080     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 512)  0           ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 256)  1179904     ['dropout_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 256)  590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 128)  295040     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 256)  0           ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 128)  295040      ['dropout_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 128)  147584      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 64)  73792       ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 128)  0           ['concatenate_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 64)   73792       ['dropout_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 64)   36928       ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 32  18464      ['conv2d_15[0][0]']
#  spose)                         )
#  concatenate_3 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 128, 128, 64  0           ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 32  18464       ['dropout_7[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 32  9248        ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 1)  33          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 5,680,865
# Trainable params: 5,680,865
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/300
# 2023-04-24 18:15:16.540520: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inU-Net/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-04-24 18:15:17.939753: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8401
# 2023-04-24 18:15:19.834933: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 80/80 [==============================] - 12s 39ms/step - loss: 1.9626 - dice_coef: 0.2480 - iou: 0.1875 - val_loss: 1.7297 - val_dice_coef: 0.1927 - val_iou: 0.1081
# Epoch 2/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.6506 - dice_coef: 0.5406 - iou: 0.4040 - val_loss: 1.2100 - val_dice_coef: 0.3117 - val_iou: 0.1908
# Epoch 3/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.3871 - dice_coef: 0.6843 - iou: 0.5448 - val_loss: 1.0658 - val_dice_coef: 0.3653 - val_iou: 0.2345
# Epoch 4/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.3569 - dice_coef: 0.7078 - iou: 0.5665 - val_loss: 0.5033 - val_dice_coef: 0.6128 - val_iou: 0.4564
# Epoch 5/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.2838 - dice_coef: 0.7571 - iou: 0.6234 - val_loss: 0.4021 - val_dice_coef: 0.6738 - val_iou: 0.5190
# Epoch 6/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.2683 - dice_coef: 0.7667 - iou: 0.6311 - val_loss: 0.4270 - val_dice_coef: 0.6590 - val_iou: 0.5068
# Epoch 7/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.2681 - dice_coef: 0.7681 - iou: 0.6327 - val_loss: 0.4353 - val_dice_coef: 0.6511 - val_iou: 0.4908
# Epoch 8/300
# 80/80 [==============================] - 3s 37ms/step - loss: 0.2598 - dice_coef: 0.7742 - iou: 0.6418 - val_loss: 0.2724 - val_dice_coef: 0.7636 - val_iou: 0.6219
# Epoch 9/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.2644 - dice_coef: 0.7707 - iou: 0.6367 - val_loss: 0.3082 - val_dice_coef: 0.7386 - val_iou: 0.5955
# Epoch 10/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.2340 - dice_coef: 0.7935 - iou: 0.6652 - val_loss: 0.3253 - val_dice_coef: 0.7269 - val_iou: 0.5797
# Epoch 11/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.2410 - dice_coef: 0.7893 - iou: 0.6602 - val_loss: 0.4009 - val_dice_coef: 0.6735 - val_iou: 0.5211
# Epoch 12/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.2275 - dice_coef: 0.7997 - iou: 0.6745 - val_loss: 0.4383 - val_dice_coef: 0.6503 - val_iou: 0.5021
# Epoch 13/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.2238 - dice_coef: 0.8016 - iou: 0.6757 - val_loss: 0.2763 - val_dice_coef: 0.7599 - val_iou: 0.6198
# Epoch 14/300
# 80/80 [==============================] - 3s 37ms/step - loss: 0.2278 - dice_coef: 0.7990 - iou: 0.6730 - val_loss: 0.2732 - val_dice_coef: 0.7637 - val_iou: 0.6233
# Epoch 15/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.2142 - dice_coef: 0.8089 - iou: 0.6854 - val_loss: 0.3020 - val_dice_coef: 0.7420 - val_iou: 0.6035
# Epoch 16/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.2150 - dice_coef: 0.8083 - iou: 0.6843 - val_loss: 0.2796 - val_dice_coef: 0.7575 - val_iou: 0.6133
# Epoch 17/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.2031 - dice_coef: 0.8175 - iou: 0.6973 - val_loss: 0.2245 - val_dice_coef: 0.8011 - val_iou: 0.6754
# Epoch 18/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.2134 - dice_coef: 0.8096 - iou: 0.6857 - val_loss: 0.2286 - val_dice_coef: 0.7968 - val_iou: 0.6699
# Epoch 19/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.2187 - dice_coef: 0.8067 - iou: 0.6835 - val_loss: 0.2321 - val_dice_coef: 0.7952 - val_iou: 0.6702
# Epoch 20/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1924 - dice_coef: 0.8264 - iou: 0.7101 - val_loss: 0.1954 - val_dice_coef: 0.8242 - val_iou: 0.7065
# Epoch 21/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.2024 - dice_coef: 0.8192 - iou: 0.7000 - val_loss: 0.1788 - val_dice_coef: 0.8373 - val_iou: 0.7235
# Epoch 22/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.2036 - dice_coef: 0.8175 - iou: 0.6973 - val_loss: 0.1819 - val_dice_coef: 0.8345 - val_iou: 0.7198
# Epoch 23/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.2099 - dice_coef: 0.8126 - iou: 0.6902 - val_loss: 0.1619 - val_dice_coef: 0.8511 - val_iou: 0.7467
# Epoch 24/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1857 - dice_coef: 0.8315 - iou: 0.7153 - val_loss: 0.1816 - val_dice_coef: 0.8349 - val_iou: 0.7210
# Epoch 25/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.2010 - dice_coef: 0.8198 - iou: 0.7003 - val_loss: 0.1881 - val_dice_coef: 0.8292 - val_iou: 0.7118
# Epoch 26/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1916 - dice_coef: 0.8269 - iou: 0.7090 - val_loss: 0.2390 - val_dice_coef: 0.7895 - val_iou: 0.6576
# Epoch 27/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1812 - dice_coef: 0.8354 - iou: 0.7223 - val_loss: 0.2054 - val_dice_coef: 0.8173 - val_iou: 0.7032
# Epoch 28/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1833 - dice_coef: 0.8336 - iou: 0.7184 - val_loss: 0.2082 - val_dice_coef: 0.8131 - val_iou: 0.6901
# Epoch 29/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1757 - dice_coef: 0.8400 - iou: 0.7281 - val_loss: 0.2324 - val_dice_coef: 0.7964 - val_iou: 0.6726
# Epoch 30/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1751 - dice_coef: 0.8407 - iou: 0.7296 - val_loss: 0.2190 - val_dice_coef: 0.8054 - val_iou: 0.6827
# Epoch 31/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1785 - dice_coef: 0.8376 - iou: 0.7248 - val_loss: 0.1564 - val_dice_coef: 0.8569 - val_iou: 0.7569
# Epoch 32/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1915 - dice_coef: 0.8277 - iou: 0.7115 - val_loss: 0.1828 - val_dice_coef: 0.8338 - val_iou: 0.7178
# Epoch 33/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1833 - dice_coef: 0.8339 - iou: 0.7191 - val_loss: 0.1934 - val_dice_coef: 0.8261 - val_iou: 0.7084
# Epoch 34/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1836 - dice_coef: 0.8341 - iou: 0.7208 - val_loss: 0.1521 - val_dice_coef: 0.8596 - val_iou: 0.7585
# Epoch 35/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1783 - dice_coef: 0.8377 - iou: 0.7255 - val_loss: 0.1627 - val_dice_coef: 0.8504 - val_iou: 0.7456
# Epoch 36/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1668 - dice_coef: 0.8475 - iou: 0.7405 - val_loss: 0.1472 - val_dice_coef: 0.8639 - val_iou: 0.7632
# Epoch 37/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1708 - dice_coef: 0.8441 - iou: 0.7343 - val_loss: 0.1465 - val_dice_coef: 0.8646 - val_iou: 0.7655
# Epoch 38/300
# 80/80 [==============================] - 3s 32ms/step - loss: 0.1691 - dice_coef: 0.8456 - iou: 0.7364 - val_loss: 0.1771 - val_dice_coef: 0.8395 - val_iou: 0.7298
# Epoch 39/300
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1720 - dice_coef: 0.8432 - iou: 0.7326 - val_loss: 0.1599 - val_dice_coef: 0.8532 - val_iou: 0.7478
# Epoch 40/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1662 - dice_coef: 0.8480 - iou: 0.7399 - val_loss: 0.1945 - val_dice_coef: 0.8249 - val_iou: 0.7064
# Epoch 41/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1706 - dice_coef: 0.8448 - iou: 0.7358 - val_loss: 0.1693 - val_dice_coef: 0.8461 - val_iou: 0.7412
# Epoch 42/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1728 - dice_coef: 0.8425 - iou: 0.7321 - val_loss: 0.1674 - val_dice_coef: 0.8473 - val_iou: 0.7391
# Epoch 43/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1758 - dice_coef: 0.8403 - iou: 0.7286 - val_loss: 0.1585 - val_dice_coef: 0.8547 - val_iou: 0.7492
# Epoch 44/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1663 - dice_coef: 0.8478 - iou: 0.7391 - val_loss: 0.1374 - val_dice_coef: 0.8726 - val_iou: 0.7779
# Epoch 45/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1584 - dice_coef: 0.8548 - iou: 0.7505 - val_loss: 0.2244 - val_dice_coef: 0.8017 - val_iou: 0.6761
# Epoch 46/300
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1680 - dice_coef: 0.8463 - iou: 0.7366 - val_loss: 0.1521 - val_dice_coef: 0.8607 - val_iou: 0.7607
# Epoch 47/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1585 - dice_coef: 0.8543 - iou: 0.7492 - val_loss: 0.1497 - val_dice_coef: 0.8623 - val_iou: 0.7626
# Epoch 48/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1584 - dice_coef: 0.8546 - iou: 0.7498 - val_loss: 0.1282 - val_dice_coef: 0.8802 - val_iou: 0.7902
# Epoch 49/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1560 - dice_coef: 0.8563 - iou: 0.7522 - val_loss: 0.1325 - val_dice_coef: 0.8764 - val_iou: 0.7820
# Epoch 50/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1553 - dice_coef: 0.8570 - iou: 0.7534 - val_loss: 0.1525 - val_dice_coef: 0.8603 - val_iou: 0.7591
# Epoch 51/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1537 - dice_coef: 0.8588 - iou: 0.7559 - val_loss: 0.1342 - val_dice_coef: 0.8750 - val_iou: 0.7821
# Epoch 52/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1485 - dice_coef: 0.8629 - iou: 0.7628 - val_loss: 0.1464 - val_dice_coef: 0.8659 - val_iou: 0.7688
# Epoch 53/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1571 - dice_coef: 0.8557 - iou: 0.7516 - val_loss: 0.1582 - val_dice_coef: 0.8573 - val_iou: 0.7573
# Epoch 54/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1530 - dice_coef: 0.8589 - iou: 0.7560 - val_loss: 0.1473 - val_dice_coef: 0.8644 - val_iou: 0.7655
# Epoch 55/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1554 - dice_coef: 0.8569 - iou: 0.7530 - val_loss: 0.1494 - val_dice_coef: 0.8623 - val_iou: 0.7612
# Epoch 56/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1495 - dice_coef: 0.8618 - iou: 0.7600 - val_loss: 0.1409 - val_dice_coef: 0.8699 - val_iou: 0.7733
# Epoch 57/300
# 80/80 [==============================] - 3s 37ms/step - loss: 0.1562 - dice_coef: 0.8563 - iou: 0.7516 - val_loss: 0.1370 - val_dice_coef: 0.8727 - val_iou: 0.7785
# Epoch 58/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1490 - dice_coef: 0.8625 - iou: 0.7622 - val_loss: 0.1506 - val_dice_coef: 0.8617 - val_iou: 0.7606
# Epoch 59/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1455 - dice_coef: 0.8653 - iou: 0.7656 - val_loss: 0.1517 - val_dice_coef: 0.8611 - val_iou: 0.7595
# Epoch 60/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1501 - dice_coef: 0.8617 - iou: 0.7606 - val_loss: 0.1315 - val_dice_coef: 0.8780 - val_iou: 0.7851
# Epoch 61/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1581 - dice_coef: 0.8551 - iou: 0.7511 - val_loss: 0.1281 - val_dice_coef: 0.8814 - val_iou: 0.7945
# Epoch 62/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1488 - dice_coef: 0.8626 - iou: 0.7615 - val_loss: 0.1255 - val_dice_coef: 0.8830 - val_iou: 0.7930
# Epoch 63/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1619 - dice_coef: 0.8515 - iou: 0.7447 - val_loss: 0.1593 - val_dice_coef: 0.8557 - val_iou: 0.7550
# Epoch 64/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1518 - dice_coef: 0.8600 - iou: 0.7576 - val_loss: 0.1198 - val_dice_coef: 0.8873 - val_iou: 0.7992
# Epoch 65/300
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1470 - dice_coef: 0.8643 - iou: 0.7635 - val_loss: 0.1420 - val_dice_coef: 0.8694 - val_iou: 0.7740
# Epoch 66/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1497 - dice_coef: 0.8619 - iou: 0.7600 - val_loss: 0.1330 - val_dice_coef: 0.8773 - val_iou: 0.7863
# Epoch 67/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1473 - dice_coef: 0.8637 - iou: 0.7621 - val_loss: 0.1429 - val_dice_coef: 0.8685 - val_iou: 0.7734
# Epoch 68/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1449 - dice_coef: 0.8658 - iou: 0.7664 - val_loss: 0.1500 - val_dice_coef: 0.8624 - val_iou: 0.7641
# Epoch 69/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1532 - dice_coef: 0.8590 - iou: 0.7558 - val_loss: 0.1355 - val_dice_coef: 0.8737 - val_iou: 0.7787
# Epoch 70/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1515 - dice_coef: 0.8603 - iou: 0.7574 - val_loss: 0.1231 - val_dice_coef: 0.8853 - val_iou: 0.7979
# Epoch 71/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1427 - dice_coef: 0.8680 - iou: 0.7696 - val_loss: 0.1303 - val_dice_coef: 0.8793 - val_iou: 0.7898
# Epoch 72/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1497 - dice_coef: 0.8619 - iou: 0.7606 - val_loss: 0.1256 - val_dice_coef: 0.8826 - val_iou: 0.7922
# Epoch 73/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1447 - dice_coef: 0.8662 - iou: 0.7677 - val_loss: 0.1568 - val_dice_coef: 0.8578 - val_iou: 0.7570
# Epoch 74/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1443 - dice_coef: 0.8664 - iou: 0.7676 - val_loss: 0.1210 - val_dice_coef: 0.8865 - val_iou: 0.8002
# Epoch 75/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1470 - dice_coef: 0.8643 - iou: 0.7645 - val_loss: 0.1324 - val_dice_coef: 0.8771 - val_iou: 0.7849
# Epoch 76/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1479 - dice_coef: 0.8633 - iou: 0.7620 - val_loss: 0.1266 - val_dice_coef: 0.8815 - val_iou: 0.7905
# Epoch 77/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1484 - dice_coef: 0.8629 - iou: 0.7620 - val_loss: 0.1186 - val_dice_coef: 0.8886 - val_iou: 0.8041
# Epoch 78/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1447 - dice_coef: 0.8660 - iou: 0.7656 - val_loss: 0.1366 - val_dice_coef: 0.8738 - val_iou: 0.7804
# Epoch 79/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1417 - dice_coef: 0.8687 - iou: 0.7709 - val_loss: 0.1280 - val_dice_coef: 0.8813 - val_iou: 0.7909
# Epoch 80/300
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1439 - dice_coef: 0.8668 - iou: 0.7677 - val_loss: 0.1440 - val_dice_coef: 0.8678 - val_iou: 0.7706
# Epoch 81/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1419 - dice_coef: 0.8684 - iou: 0.7701 - val_loss: 0.1308 - val_dice_coef: 0.8789 - val_iou: 0.7888
# Epoch 82/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1380 - dice_coef: 0.8718 - iou: 0.7756 - val_loss: 0.1242 - val_dice_coef: 0.8846 - val_iou: 0.7976
# Epoch 83/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1419 - dice_coef: 0.8684 - iou: 0.7691 - val_loss: 0.1457 - val_dice_coef: 0.8672 - val_iou: 0.7713
# Epoch 84/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1428 - dice_coef: 0.8676 - iou: 0.7689 - val_loss: 0.1204 - val_dice_coef: 0.8870 - val_iou: 0.8001
# Epoch 85/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1401 - dice_coef: 0.8699 - iou: 0.7718 - val_loss: 0.1488 - val_dice_coef: 0.8640 - val_iou: 0.7665
# Epoch 86/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1422 - dice_coef: 0.8682 - iou: 0.7700 - val_loss: 0.1433 - val_dice_coef: 0.8687 - val_iou: 0.7733
# Epoch 87/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1524 - dice_coef: 0.8598 - iou: 0.7571 - val_loss: 0.1260 - val_dice_coef: 0.8837 - val_iou: 0.7957
# Epoch 88/300
# 80/80 [==============================] - 3s 37ms/step - loss: 0.1429 - dice_coef: 0.8679 - iou: 0.7704 - val_loss: 0.1450 - val_dice_coef: 0.8658 - val_iou: 0.7666
# Epoch 89/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1351 - dice_coef: 0.8743 - iou: 0.7800 - val_loss: 0.1338 - val_dice_coef: 0.8758 - val_iou: 0.7819
# Epoch 90/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1323 - dice_coef: 0.8766 - iou: 0.7825 - val_loss: 0.1282 - val_dice_coef: 0.8803 - val_iou: 0.7880
# Epoch 91/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1466 - dice_coef: 0.8647 - iou: 0.7646 - val_loss: 0.1402 - val_dice_coef: 0.8711 - val_iou: 0.7766
# Epoch 92/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1426 - dice_coef: 0.8681 - iou: 0.7697 - val_loss: 0.1149 - val_dice_coef: 0.8919 - val_iou: 0.8079
# Epoch 93/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1322 - dice_coef: 0.8767 - iou: 0.7826 - val_loss: 0.1274 - val_dice_coef: 0.8820 - val_iou: 0.7933
# Epoch 94/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1321 - dice_coef: 0.8768 - iou: 0.7838 - val_loss: 0.1327 - val_dice_coef: 0.8776 - val_iou: 0.7853
# Epoch 95/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1360 - dice_coef: 0.8734 - iou: 0.7772 - val_loss: 0.1352 - val_dice_coef: 0.8751 - val_iou: 0.7815
# Epoch 96/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1298 - dice_coef: 0.8790 - iou: 0.7869 - val_loss: 0.1352 - val_dice_coef: 0.8743 - val_iou: 0.7795
# Epoch 97/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1348 - dice_coef: 0.8747 - iou: 0.7793 - val_loss: 0.1386 - val_dice_coef: 0.8726 - val_iou: 0.7787
# Epoch 98/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1391 - dice_coef: 0.8709 - iou: 0.7740 - val_loss: 0.1329 - val_dice_coef: 0.8763 - val_iou: 0.7811
# Epoch 99/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1275 - dice_coef: 0.8809 - iou: 0.7895 - val_loss: 0.1209 - val_dice_coef: 0.8865 - val_iou: 0.7978
# Epoch 100/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1317 - dice_coef: 0.8774 - iou: 0.7840 - val_loss: 0.1354 - val_dice_coef: 0.8748 - val_iou: 0.7813
# Epoch 101/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1324 - dice_coef: 0.8767 - iou: 0.7828 - val_loss: 0.1312 - val_dice_coef: 0.8787 - val_iou: 0.7874
# Epoch 102/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1302 - dice_coef: 0.8785 - iou: 0.7853 - val_loss: 0.1268 - val_dice_coef: 0.8816 - val_iou: 0.7900
# Epoch 103/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1290 - dice_coef: 0.8796 - iou: 0.7872 - val_loss: 0.1249 - val_dice_coef: 0.8841 - val_iou: 0.7950
# Epoch 104/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1364 - dice_coef: 0.8733 - iou: 0.7779 - val_loss: 0.1311 - val_dice_coef: 0.8784 - val_iou: 0.7850
# Epoch 105/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1353 - dice_coef: 0.8741 - iou: 0.7790 - val_loss: 0.1203 - val_dice_coef: 0.8873 - val_iou: 0.7982
# Epoch 106/300
# 80/80 [==============================] - 3s 37ms/step - loss: 0.1282 - dice_coef: 0.8803 - iou: 0.7883 - val_loss: 0.1373 - val_dice_coef: 0.8725 - val_iou: 0.7763
# Epoch 107/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1336 - dice_coef: 0.8755 - iou: 0.7807 - val_loss: 0.1219 - val_dice_coef: 0.8871 - val_iou: 0.8018
# Epoch 108/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1367 - dice_coef: 0.8731 - iou: 0.7778 - val_loss: 0.1361 - val_dice_coef: 0.8753 - val_iou: 0.7840
# Epoch 109/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1307 - dice_coef: 0.8780 - iou: 0.7844 - val_loss: 0.1168 - val_dice_coef: 0.8900 - val_iou: 0.8044
# Epoch 110/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1304 - dice_coef: 0.8783 - iou: 0.7855 - val_loss: 0.1327 - val_dice_coef: 0.8768 - val_iou: 0.7823
# Epoch 111/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1308 - dice_coef: 0.8780 - iou: 0.7842 - val_loss: 0.1237 - val_dice_coef: 0.8840 - val_iou: 0.7946
# Epoch 112/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1286 - dice_coef: 0.8799 - iou: 0.7875 - val_loss: 0.1429 - val_dice_coef: 0.8700 - val_iou: 0.7763
# Epoch 113/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1253 - dice_coef: 0.8826 - iou: 0.7915 - val_loss: 0.1302 - val_dice_coef: 0.8792 - val_iou: 0.7890
# Epoch 114/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1319 - dice_coef: 0.8769 - iou: 0.7824 - val_loss: 0.1170 - val_dice_coef: 0.8898 - val_iou: 0.8036
# Epoch 115/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1279 - dice_coef: 0.8806 - iou: 0.7894 - val_loss: 0.1264 - val_dice_coef: 0.8822 - val_iou: 0.7913
# Epoch 116/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1316 - dice_coef: 0.8774 - iou: 0.7843 - val_loss: 0.1467 - val_dice_coef: 0.8655 - val_iou: 0.7655
# Epoch 117/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1261 - dice_coef: 0.8819 - iou: 0.7905 - val_loss: 0.1207 - val_dice_coef: 0.8881 - val_iou: 0.8023
# Epoch 118/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1289 - dice_coef: 0.8798 - iou: 0.7880 - val_loss: 0.1309 - val_dice_coef: 0.8789 - val_iou: 0.7884
# Epoch 119/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1279 - dice_coef: 0.8806 - iou: 0.7894 - val_loss: 0.1320 - val_dice_coef: 0.8773 - val_iou: 0.7842
# Epoch 120/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1323 - dice_coef: 0.8767 - iou: 0.7821 - val_loss: 0.1258 - val_dice_coef: 0.8824 - val_iou: 0.7908
# Epoch 121/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1272 - dice_coef: 0.8811 - iou: 0.7896 - val_loss: 0.1236 - val_dice_coef: 0.8853 - val_iou: 0.7977
# Epoch 122/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1268 - dice_coef: 0.8814 - iou: 0.7899 - val_loss: 0.1398 - val_dice_coef: 0.8717 - val_iou: 0.7768
# Epoch 123/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1262 - dice_coef: 0.8821 - iou: 0.7910 - val_loss: 0.1298 - val_dice_coef: 0.8786 - val_iou: 0.7848
# Epoch 124/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1240 - dice_coef: 0.8841 - iou: 0.7943 - val_loss: 0.1219 - val_dice_coef: 0.8863 - val_iou: 0.7991
# Epoch 125/300
# 80/80 [==============================] - 3s 37ms/step - loss: 0.1287 - dice_coef: 0.8798 - iou: 0.7871 - val_loss: 0.1139 - val_dice_coef: 0.8928 - val_iou: 0.8090
# Epoch 126/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1265 - dice_coef: 0.8817 - iou: 0.7908 - val_loss: 0.1279 - val_dice_coef: 0.8810 - val_iou: 0.7889
# Epoch 127/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1264 - dice_coef: 0.8819 - iou: 0.7907 - val_loss: 0.1589 - val_dice_coef: 0.8541 - val_iou: 0.7483
# Epoch 128/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1328 - dice_coef: 0.8762 - iou: 0.7815 - val_loss: 0.1144 - val_dice_coef: 0.8944 - val_iou: 0.8145
# Epoch 129/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1266 - dice_coef: 0.8816 - iou: 0.7902 - val_loss: 0.1490 - val_dice_coef: 0.8633 - val_iou: 0.7649
# Epoch 130/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1279 - dice_coef: 0.8805 - iou: 0.7878 - val_loss: 0.1122 - val_dice_coef: 0.8944 - val_iou: 0.8112
# Epoch 131/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1250 - dice_coef: 0.8832 - iou: 0.7922 - val_loss: 0.1450 - val_dice_coef: 0.8670 - val_iou: 0.7709
# Epoch 132/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1267 - dice_coef: 0.8815 - iou: 0.7898 - val_loss: 0.1109 - val_dice_coef: 0.8953 - val_iou: 0.8130
# Epoch 133/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1238 - dice_coef: 0.8841 - iou: 0.7950 - val_loss: 0.1382 - val_dice_coef: 0.8731 - val_iou: 0.7799
# Epoch 134/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1246 - dice_coef: 0.8833 - iou: 0.7932 - val_loss: 0.1255 - val_dice_coef: 0.8840 - val_iou: 0.7952
# Epoch 135/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1218 - dice_coef: 0.8858 - iou: 0.7968 - val_loss: 0.1271 - val_dice_coef: 0.8830 - val_iou: 0.7958
# Epoch 136/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1234 - dice_coef: 0.8844 - iou: 0.7944 - val_loss: 0.1237 - val_dice_coef: 0.8845 - val_iou: 0.7945
# Epoch 137/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1259 - dice_coef: 0.8823 - iou: 0.7919 - val_loss: 0.1348 - val_dice_coef: 0.8752 - val_iou: 0.7811
# Epoch 138/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1192 - dice_coef: 0.8881 - iou: 0.8005 - val_loss: 0.1211 - val_dice_coef: 0.8871 - val_iou: 0.7989
# Epoch 139/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1275 - dice_coef: 0.8809 - iou: 0.7902 - val_loss: 0.1205 - val_dice_coef: 0.8874 - val_iou: 0.8000
# Epoch 140/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1262 - dice_coef: 0.8821 - iou: 0.7912 - val_loss: 0.1189 - val_dice_coef: 0.8890 - val_iou: 0.8036
# Epoch 141/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1241 - dice_coef: 0.8840 - iou: 0.7936 - val_loss: 0.1303 - val_dice_coef: 0.8799 - val_iou: 0.7906
# Epoch 142/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1243 - dice_coef: 0.8838 - iou: 0.7949 - val_loss: 0.1192 - val_dice_coef: 0.8892 - val_iou: 0.8044
# Epoch 143/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1242 - dice_coef: 0.8838 - iou: 0.7938 - val_loss: 0.1252 - val_dice_coef: 0.8836 - val_iou: 0.7952
# Epoch 144/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1197 - dice_coef: 0.8876 - iou: 0.7999 - val_loss: 0.1448 - val_dice_coef: 0.8680 - val_iou: 0.7722
# Epoch 145/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1242 - dice_coef: 0.8838 - iou: 0.7939 - val_loss: 0.1155 - val_dice_coef: 0.8913 - val_iou: 0.8053
# Epoch 146/300
# 80/80 [==============================] - 3s 37ms/step - loss: 0.1234 - dice_coef: 0.8844 - iou: 0.7942 - val_loss: 0.1236 - val_dice_coef: 0.8853 - val_iou: 0.7976
# Epoch 147/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1258 - dice_coef: 0.8823 - iou: 0.7912 - val_loss: 0.1215 - val_dice_coef: 0.8863 - val_iou: 0.7983
# Epoch 148/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1255 - dice_coef: 0.8826 - iou: 0.7920 - val_loss: 0.1261 - val_dice_coef: 0.8830 - val_iou: 0.7932
# Epoch 149/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1236 - dice_coef: 0.8842 - iou: 0.7946 - val_loss: 0.1137 - val_dice_coef: 0.8933 - val_iou: 0.8105
# Epoch 150/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1359 - dice_coef: 0.8737 - iou: 0.7777 - val_loss: 0.1368 - val_dice_coef: 0.8736 - val_iou: 0.7790
# Epoch 151/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1236 - dice_coef: 0.8842 - iou: 0.7941 - val_loss: 0.1155 - val_dice_coef: 0.8927 - val_iou: 0.8100
# Epoch 152/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1194 - dice_coef: 0.8880 - iou: 0.8006 - val_loss: 0.1537 - val_dice_coef: 0.8606 - val_iou: 0.7616
# Epoch 153/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1161 - dice_coef: 0.8907 - iou: 0.8048 - val_loss: 0.1111 - val_dice_coef: 0.8954 - val_iou: 0.8147
# Epoch 154/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1163 - dice_coef: 0.8907 - iou: 0.8043 - val_loss: 0.1236 - val_dice_coef: 0.8845 - val_iou: 0.7958
# Epoch 155/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1191 - dice_coef: 0.8882 - iou: 0.8007 - val_loss: 0.1220 - val_dice_coef: 0.8863 - val_iou: 0.7995
# Epoch 156/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1259 - dice_coef: 0.8823 - iou: 0.7911 - val_loss: 0.1164 - val_dice_coef: 0.8907 - val_iou: 0.8032
# Epoch 157/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1183 - dice_coef: 0.8891 - iou: 0.8024 - val_loss: 0.1212 - val_dice_coef: 0.8870 - val_iou: 0.7998
# Epoch 158/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1208 - dice_coef: 0.8868 - iou: 0.7993 - val_loss: 0.1170 - val_dice_coef: 0.8900 - val_iou: 0.8028
# Epoch 159/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1190 - dice_coef: 0.8884 - iou: 0.8010 - val_loss: 0.1287 - val_dice_coef: 0.8813 - val_iou: 0.7925
# Epoch 160/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1272 - dice_coef: 0.8812 - iou: 0.7894 - val_loss: 0.1235 - val_dice_coef: 0.8854 - val_iou: 0.7974
# Epoch 161/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1217 - dice_coef: 0.8858 - iou: 0.7964 - val_loss: 0.1264 - val_dice_coef: 0.8831 - val_iou: 0.7944
# Epoch 162/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1196 - dice_coef: 0.8878 - iou: 0.7999 - val_loss: 0.1240 - val_dice_coef: 0.8845 - val_iou: 0.7952
# Epoch 163/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1238 - dice_coef: 0.8841 - iou: 0.7940 - val_loss: 0.1100 - val_dice_coef: 0.8960 - val_iou: 0.8141
# Epoch 164/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1190 - dice_coef: 0.8887 - iou: 0.8017 - val_loss: 0.1118 - val_dice_coef: 0.8953 - val_iou: 0.8139
# Epoch 165/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1188 - dice_coef: 0.8884 - iou: 0.8009 - val_loss: 0.1274 - val_dice_coef: 0.8816 - val_iou: 0.7921
# Epoch 166/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1167 - dice_coef: 0.8903 - iou: 0.8044 - val_loss: 0.1269 - val_dice_coef: 0.8815 - val_iou: 0.7897
# Epoch 167/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1217 - dice_coef: 0.8861 - iou: 0.7978 - val_loss: 0.1239 - val_dice_coef: 0.8839 - val_iou: 0.7952
# Epoch 168/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1214 - dice_coef: 0.8862 - iou: 0.7975 - val_loss: 0.1488 - val_dice_coef: 0.8649 - val_iou: 0.7672
# Epoch 169/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1227 - dice_coef: 0.8853 - iou: 0.7963 - val_loss: 0.1210 - val_dice_coef: 0.8862 - val_iou: 0.7968
# Epoch 170/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1226 - dice_coef: 0.8851 - iou: 0.7955 - val_loss: 0.1404 - val_dice_coef: 0.8713 - val_iou: 0.7760
# Epoch 171/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1188 - dice_coef: 0.8885 - iou: 0.8018 - val_loss: 0.1233 - val_dice_coef: 0.8846 - val_iou: 0.7943
# Epoch 172/300
# 80/80 [==============================] - 3s 37ms/step - loss: 0.1155 - dice_coef: 0.8914 - iou: 0.8058 - val_loss: 0.1120 - val_dice_coef: 0.8949 - val_iou: 0.8124
# Epoch 173/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1124 - dice_coef: 0.8942 - iou: 0.8109 - val_loss: 0.1325 - val_dice_coef: 0.8775 - val_iou: 0.7856
# Epoch 174/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1211 - dice_coef: 0.8865 - iou: 0.7974 - val_loss: 0.1302 - val_dice_coef: 0.8793 - val_iou: 0.7886
# Epoch 175/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1198 - dice_coef: 0.8877 - iou: 0.7996 - val_loss: 0.1258 - val_dice_coef: 0.8829 - val_iou: 0.7928
# Epoch 176/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1136 - dice_coef: 0.8931 - iou: 0.8085 - val_loss: 0.1183 - val_dice_coef: 0.8888 - val_iou: 0.8009
# Epoch 177/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1140 - dice_coef: 0.8927 - iou: 0.8075 - val_loss: 0.1295 - val_dice_coef: 0.8796 - val_iou: 0.7877
# Epoch 178/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1159 - dice_coef: 0.8911 - iou: 0.8056 - val_loss: 0.1128 - val_dice_coef: 0.8940 - val_iou: 0.8100
# Epoch 179/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1157 - dice_coef: 0.8911 - iou: 0.8053 - val_loss: 0.1222 - val_dice_coef: 0.8858 - val_iou: 0.7975
# Epoch 180/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1180 - dice_coef: 0.8890 - iou: 0.8017 - val_loss: 0.1200 - val_dice_coef: 0.8878 - val_iou: 0.8010
# Epoch 181/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1127 - dice_coef: 0.8939 - iou: 0.8101 - val_loss: 0.1254 - val_dice_coef: 0.8833 - val_iou: 0.7936
# Epoch 182/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1208 - dice_coef: 0.8868 - iou: 0.7985 - val_loss: 0.1138 - val_dice_coef: 0.8932 - val_iou: 0.8089
# Epoch 183/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1153 - dice_coef: 0.8916 - iou: 0.8058 - val_loss: 0.1090 - val_dice_coef: 0.8978 - val_iou: 0.8167
# Epoch 184/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1170 - dice_coef: 0.8901 - iou: 0.8034 - val_loss: 0.1135 - val_dice_coef: 0.8937 - val_iou: 0.8109
# Epoch 185/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1172 - dice_coef: 0.8900 - iou: 0.8037 - val_loss: 0.1167 - val_dice_coef: 0.8914 - val_iou: 0.8073
# Epoch 186/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1173 - dice_coef: 0.8898 - iou: 0.8030 - val_loss: 0.1149 - val_dice_coef: 0.8927 - val_iou: 0.8097
# Epoch 187/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1158 - dice_coef: 0.8911 - iou: 0.8056 - val_loss: 0.1395 - val_dice_coef: 0.8719 - val_iou: 0.7774
# Epoch 188/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1248 - dice_coef: 0.8833 - iou: 0.7927 - val_loss: 0.1049 - val_dice_coef: 0.9007 - val_iou: 0.8199
# Epoch 189/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1126 - dice_coef: 0.8941 - iou: 0.8106 - val_loss: 0.1284 - val_dice_coef: 0.8816 - val_iou: 0.7934
# Epoch 190/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1212 - dice_coef: 0.8864 - iou: 0.7972 - val_loss: 0.1293 - val_dice_coef: 0.8802 - val_iou: 0.7901
# Epoch 191/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1179 - dice_coef: 0.8891 - iou: 0.8017 - val_loss: 0.1133 - val_dice_coef: 0.8940 - val_iou: 0.8122
# Epoch 192/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1146 - dice_coef: 0.8922 - iou: 0.8063 - val_loss: 0.1090 - val_dice_coef: 0.8971 - val_iou: 0.8149
# Epoch 193/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1112 - dice_coef: 0.8952 - iou: 0.8113 - val_loss: 0.1237 - val_dice_coef: 0.8847 - val_iou: 0.7965
# Epoch 194/300
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1109 - dice_coef: 0.8954 - iou: 0.8118 - val_loss: 0.1075 - val_dice_coef: 0.8992 - val_iou: 0.8200
# Epoch 195/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1153 - dice_coef: 0.8916 - iou: 0.8068 - val_loss: 0.1223 - val_dice_coef: 0.8858 - val_iou: 0.7982
# Epoch 196/300
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1154 - dice_coef: 0.8916 - iou: 0.8064 - val_loss: 0.1143 - val_dice_coef: 0.8932 - val_iou: 0.8112
# Epoch 197/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1154 - dice_coef: 0.8915 - iou: 0.8054 - val_loss: 0.1087 - val_dice_coef: 0.8972 - val_iou: 0.8132
# Epoch 198/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1129 - dice_coef: 0.8937 - iou: 0.8096 - val_loss: 0.1185 - val_dice_coef: 0.8885 - val_iou: 0.8009
# Epoch 199/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1135 - dice_coef: 0.8931 - iou: 0.8077 - val_loss: 0.1311 - val_dice_coef: 0.8787 - val_iou: 0.7865
# Epoch 200/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1094 - dice_coef: 0.8968 - iou: 0.8151 - val_loss: 0.1181 - val_dice_coef: 0.8892 - val_iou: 0.8027
# Epoch 201/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1102 - dice_coef: 0.8960 - iou: 0.8126 - val_loss: 0.1153 - val_dice_coef: 0.8925 - val_iou: 0.8092
# Epoch 202/300
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1119 - dice_coef: 0.8945 - iou: 0.8110 - val_loss: 0.1160 - val_dice_coef: 0.8916 - val_iou: 0.8084
# Epoch 203/300
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1140 - dice_coef: 0.8929 - iou: 0.8083 - val_loss: 0.1286 - val_dice_coef: 0.8805 - val_iou: 0.7895
# Epoch 204/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1157 - dice_coef: 0.8913 - iou: 0.8060 - val_loss: 0.1101 - val_dice_coef: 0.8961 - val_iou: 0.8133
# Epoch 205/300
# 80/80 [==============================] - 3s 33ms/step - loss: 0.1148 - dice_coef: 0.8922 - iou: 0.8072 - val_loss: 0.1300 - val_dice_coef: 0.8787 - val_iou: 0.7852
# Epoch 206/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1190 - dice_coef: 0.8884 - iou: 0.8014 - val_loss: 0.1207 - val_dice_coef: 0.8869 - val_iou: 0.7990
# Epoch 207/300
# ...
# Epoch 212/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1091 - dice_coef: 0.8972 - iou: 0.8150 - val_loss: 0.1251 - val_dice_coef: 0.8843 - val_iou: 0.7978
# Epoch 213/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1104 - dice_coef: 0.8960 - iou: 0.8130 - val_loss: 0.1112 - val_dice_coef: 0.8954 - val_iou: 0.8140
# Epoch 214/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1126 - dice_coef: 0.8939 - iou: 0.8096 - val_loss: 0.1262 - val_dice_coef: 0.8830 - val_iou: 0.7920
# Epoch 215/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1110 - dice_coef: 0.8954 - iou: 0.8123 - val_loss: 0.1030 - val_dice_coef: 0.9024 - val_iou: 0.8230
# Epoch 216/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1124 - dice_coef: 0.8941 - iou: 0.8107 - val_loss: 0.1276 - val_dice_coef: 0.8821 - val_iou: 0.7933
# Epoch 217/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1081 - dice_coef: 0.8979 - iou: 0.8161 - val_loss: 0.1206 - val_dice_coef: 0.8872 - val_iou: 0.7992
# Epoch 218/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1091 - dice_coef: 0.8970 - iou: 0.8148 - val_loss: 0.1116 - val_dice_coef: 0.8954 - val_iou: 0.8133
# Epoch 219/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1098 - dice_coef: 0.8964 - iou: 0.8139 - val_loss: 0.1304 - val_dice_coef: 0.8793 - val_iou: 0.7882
# Epoch 220/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1130 - dice_coef: 0.8936 - iou: 0.8093 - val_loss: 0.1224 - val_dice_coef: 0.8864 - val_iou: 0.8001
# Epoch 221/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1131 - dice_coef: 0.8936 - iou: 0.8099 - val_loss: 0.1216 - val_dice_coef: 0.8869 - val_iou: 0.8005
# Epoch 222/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1107 - dice_coef: 0.8956 - iou: 0.8129 - val_loss: 0.1213 - val_dice_coef: 0.8871 - val_iou: 0.8001
# Epoch 223/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1094 - dice_coef: 0.8969 - iou: 0.8145 - val_loss: 0.1232 - val_dice_coef: 0.8847 - val_iou: 0.7955
# Epoch 224/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1103 - dice_coef: 0.8959 - iou: 0.8126 - val_loss: 0.1226 - val_dice_coef: 0.8860 - val_iou: 0.7987
# Epoch 225/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1095 - dice_coef: 0.8967 - iou: 0.8139 - val_loss: 0.1169 - val_dice_coef: 0.8908 - val_iou: 0.8069
# Epoch 226/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1100 - dice_coef: 0.8963 - iou: 0.8138 - val_loss: 0.1248 - val_dice_coef: 0.8837 - val_iou: 0.7945
# Epoch 227/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1146 - dice_coef: 0.8920 - iou: 0.8063 - val_loss: 0.1251 - val_dice_coef: 0.8836 - val_iou: 0.7950
# Epoch 228/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1085 - dice_coef: 0.8976 - iou: 0.8149 - val_loss: 0.1048 - val_dice_coef: 0.9010 - val_iou: 0.8223
# Epoch 229/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1057 - dice_coef: 0.9000 - iou: 0.8196 - val_loss: 0.1215 - val_dice_coef: 0.8860 - val_iou: 0.7961
# Epoch 230/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1116 - dice_coef: 0.8950 - iou: 0.8123 - val_loss: 0.1183 - val_dice_coef: 0.8890 - val_iou: 0.8015
# Epoch 231/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1096 - dice_coef: 0.8966 - iou: 0.8146 - val_loss: 0.1347 - val_dice_coef: 0.8755 - val_iou: 0.7820
# Epoch 232/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1110 - dice_coef: 0.8955 - iou: 0.8128 - val_loss: 0.1208 - val_dice_coef: 0.8883 - val_iou: 0.8032
# Epoch 233/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1109 - dice_coef: 0.8955 - iou: 0.8119 - val_loss: 0.1320 - val_dice_coef: 0.8783 - val_iou: 0.7868
# Epoch 234/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1145 - dice_coef: 0.8922 - iou: 0.8069 - val_loss: 0.1290 - val_dice_coef: 0.8801 - val_iou: 0.7875
# Epoch 235/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1120 - dice_coef: 0.8946 - iou: 0.8109 - val_loss: 0.1137 - val_dice_coef: 0.8931 - val_iou: 0.8084
# Epoch 236/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1124 - dice_coef: 0.8942 - iou: 0.8100 - val_loss: 0.1115 - val_dice_coef: 0.8957 - val_iou: 0.8137
# Epoch 237/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1076 - dice_coef: 0.8985 - iou: 0.8172 - val_loss: 0.1202 - val_dice_coef: 0.8874 - val_iou: 0.7994
# Epoch 238/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1041 - dice_coef: 0.9015 - iou: 0.8226 - val_loss: 0.1365 - val_dice_coef: 0.8740 - val_iou: 0.7809
# Epoch 239/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1074 - dice_coef: 0.8987 - iou: 0.8177 - val_loss: 0.1115 - val_dice_coef: 0.8959 - val_iou: 0.8148
# Epoch 240/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1082 - dice_coef: 0.8978 - iou: 0.8156 - val_loss: 0.1188 - val_dice_coef: 0.8895 - val_iou: 0.8033
# Epoch 241/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1106 - dice_coef: 0.8960 - iou: 0.8136 - val_loss: 0.1135 - val_dice_coef: 0.8936 - val_iou: 0.8098
# Epoch 242/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1088 - dice_coef: 0.8973 - iou: 0.8157 - val_loss: 0.1201 - val_dice_coef: 0.8883 - val_iou: 0.8020
# Epoch 243/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1098 - dice_coef: 0.8964 - iou: 0.8138 - val_loss: 0.1123 - val_dice_coef: 0.8945 - val_iou: 0.8108
# Epoch 244/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1068 - dice_coef: 0.8992 - iou: 0.8185 - val_loss: 0.1082 - val_dice_coef: 0.8978 - val_iou: 0.8158
# Epoch 245/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1054 - dice_coef: 0.9004 - iou: 0.8201 - val_loss: 0.1327 - val_dice_coef: 0.8775 - val_iou: 0.7850
# Epoch 246/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1085 - dice_coef: 0.8976 - iou: 0.8154 - val_loss: 0.1105 - val_dice_coef: 0.8959 - val_iou: 0.8123
# Epoch 247/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1127 - dice_coef: 0.8939 - iou: 0.8098 - val_loss: 0.1170 - val_dice_coef: 0.8902 - val_iou: 0.8041
# Epoch 248/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1096 - dice_coef: 0.8967 - iou: 0.8143 - val_loss: 0.1316 - val_dice_coef: 0.8788 - val_iou: 0.7885
# Epoch 249/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1113 - dice_coef: 0.8952 - iou: 0.8115 - val_loss: 0.1164 - val_dice_coef: 0.8907 - val_iou: 0.8054
# Epoch 250/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1078 - dice_coef: 0.8983 - iou: 0.8171 - val_loss: 0.1240 - val_dice_coef: 0.8853 - val_iou: 0.7984
# Epoch 251/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1044 - dice_coef: 0.9013 - iou: 0.8219 - val_loss: 0.1244 - val_dice_coef: 0.8844 - val_iou: 0.7955
# Epoch 252/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1134 - dice_coef: 0.8935 - iou: 0.8096 - val_loss: 0.1378 - val_dice_coef: 0.8742 - val_iou: 0.7823
# Epoch 253/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1078 - dice_coef: 0.8982 - iou: 0.8164 - val_loss: 0.1087 - val_dice_coef: 0.8973 - val_iou: 0.8151
# Epoch 254/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1030 - dice_coef: 0.9025 - iou: 0.8236 - val_loss: 0.1152 - val_dice_coef: 0.8921 - val_iou: 0.8069
# Epoch 255/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1083 - dice_coef: 0.8978 - iou: 0.8161 - val_loss: 0.1411 - val_dice_coef: 0.8707 - val_iou: 0.7759
# Epoch 256/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1133 - dice_coef: 0.8934 - iou: 0.8087 - val_loss: 0.1206 - val_dice_coef: 0.8883 - val_iou: 0.8030
# Epoch 257/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1074 - dice_coef: 0.8987 - iou: 0.8177 - val_loss: 0.1251 - val_dice_coef: 0.8846 - val_iou: 0.7973
# Epoch 258/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1071 - dice_coef: 0.8988 - iou: 0.8176 - val_loss: 0.1197 - val_dice_coef: 0.8881 - val_iou: 0.8000
# Epoch 259/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1081 - dice_coef: 0.8979 - iou: 0.8162 - val_loss: 0.1257 - val_dice_coef: 0.8834 - val_iou: 0.7935
# Epoch 260/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1075 - dice_coef: 0.8986 - iou: 0.8170 - val_loss: 0.1260 - val_dice_coef: 0.8837 - val_iou: 0.7967
# Epoch 261/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1013 - dice_coef: 0.9040 - iou: 0.8263 - val_loss: 0.1199 - val_dice_coef: 0.8879 - val_iou: 0.8012
# Epoch 262/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1061 - dice_coef: 0.8997 - iou: 0.8192 - val_loss: 0.1215 - val_dice_coef: 0.8868 - val_iou: 0.7994
# Epoch 263/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1048 - dice_coef: 0.9009 - iou: 0.8208 - val_loss: 0.1190 - val_dice_coef: 0.8891 - val_iou: 0.8034
# Epoch 264/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1088 - dice_coef: 0.8975 - iou: 0.8155 - val_loss: 0.1289 - val_dice_coef: 0.8809 - val_iou: 0.7912
# Epoch 265/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1130 - dice_coef: 0.8937 - iou: 0.8095 - val_loss: 0.1293 - val_dice_coef: 0.8790 - val_iou: 0.7851
# Epoch 266/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1100 - dice_coef: 0.8962 - iou: 0.8130 - val_loss: 0.1181 - val_dice_coef: 0.8895 - val_iou: 0.8044
# Epoch 267/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1033 - dice_coef: 0.9023 - iou: 0.8239 - val_loss: 0.1261 - val_dice_coef: 0.8831 - val_iou: 0.7949
# Epoch 268/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1070 - dice_coef: 0.8990 - iou: 0.8173 - val_loss: 0.1187 - val_dice_coef: 0.8894 - val_iou: 0.8031
# Epoch 269/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1030 - dice_coef: 0.9026 - iou: 0.8241 - val_loss: 0.1332 - val_dice_coef: 0.8775 - val_iou: 0.7858
# Epoch 270/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.0995 - dice_coef: 0.9056 - iou: 0.8287 - val_loss: 0.1114 - val_dice_coef: 0.8950 - val_iou: 0.8105
# Epoch 271/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1037 - dice_coef: 0.9018 - iou: 0.8216 - val_loss: 0.1307 - val_dice_coef: 0.8795 - val_iou: 0.7896
# Epoch 272/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1052 - dice_coef: 0.9008 - iou: 0.8217 - val_loss: 0.1248 - val_dice_coef: 0.8841 - val_iou: 0.7951
# Epoch 273/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1030 - dice_coef: 0.9025 - iou: 0.8239 - val_loss: 0.1349 - val_dice_coef: 0.8746 - val_iou: 0.7795
# Epoch 274/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1038 - dice_coef: 0.9017 - iou: 0.8221 - val_loss: 0.1058 - val_dice_coef: 0.8998 - val_iou: 0.8183
# Epoch 275/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1058 - dice_coef: 0.9001 - iou: 0.8197 - val_loss: 0.1190 - val_dice_coef: 0.8890 - val_iou: 0.8040
# Epoch 276/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1050 - dice_coef: 0.9007 - iou: 0.8204 - val_loss: 0.1269 - val_dice_coef: 0.8827 - val_iou: 0.7951
# Epoch 277/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1068 - dice_coef: 0.8992 - iou: 0.8187 - val_loss: 0.1103 - val_dice_coef: 0.8963 - val_iou: 0.8137
# Epoch 278/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1018 - dice_coef: 0.9035 - iou: 0.8256 - val_loss: 0.1234 - val_dice_coef: 0.8853 - val_iou: 0.7984
# Epoch 279/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1034 - dice_coef: 0.9022 - iou: 0.8232 - val_loss: 0.1150 - val_dice_coef: 0.8921 - val_iou: 0.8081
# Epoch 280/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1054 - dice_coef: 0.9003 - iou: 0.8197 - val_loss: 0.1145 - val_dice_coef: 0.8927 - val_iou: 0.8090
# Epoch 281/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1057 - dice_coef: 0.9002 - iou: 0.8197 - val_loss: 0.1090 - val_dice_coef: 0.8974 - val_iou: 0.8150
# Epoch 282/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1010 - dice_coef: 0.9042 - iou: 0.8266 - val_loss: 0.1269 - val_dice_coef: 0.8822 - val_iou: 0.7937
# Epoch 283/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1059 - dice_coef: 0.8998 - iou: 0.8191 - val_loss: 0.1242 - val_dice_coef: 0.8841 - val_iou: 0.7942
# Epoch 284/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1029 - dice_coef: 0.9027 - iou: 0.8241 - val_loss: 0.1295 - val_dice_coef: 0.8801 - val_iou: 0.7899
# Epoch 285/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1032 - dice_coef: 0.9023 - iou: 0.8232 - val_loss: 0.1113 - val_dice_coef: 0.8953 - val_iou: 0.8116
# Epoch 286/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1017 - dice_coef: 0.9037 - iou: 0.8261 - val_loss: 0.1166 - val_dice_coef: 0.8904 - val_iou: 0.8034
# Epoch 287/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1035 - dice_coef: 0.9021 - iou: 0.8228 - val_loss: 0.1142 - val_dice_coef: 0.8930 - val_iou: 0.8080
# Epoch 288/300
# 80/80 [==============================] - 3s 36ms/step - loss: 0.1070 - dice_coef: 0.8990 - iou: 0.8176 - val_loss: 0.1251 - val_dice_coef: 0.8845 - val_iou: 0.7981
# Epoch 289/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1020 - dice_coef: 0.9033 - iou: 0.8250 - val_loss: 0.1186 - val_dice_coef: 0.8892 - val_iou: 0.8024
# Epoch 290/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1076 - dice_coef: 0.8985 - iou: 0.8171 - val_loss: 0.1133 - val_dice_coef: 0.8934 - val_iou: 0.8079
# Epoch 291/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1085 - dice_coef: 0.8976 - iou: 0.8160 - val_loss: 0.1349 - val_dice_coef: 0.8759 - val_iou: 0.7840
# Epoch 292/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1071 - dice_coef: 0.8988 - iou: 0.8173 - val_loss: 0.1126 - val_dice_coef: 0.8937 - val_iou: 0.8083
# Epoch 293/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1041 - dice_coef: 0.9016 - iou: 0.8227 - val_loss: 0.1327 - val_dice_coef: 0.8784 - val_iou: 0.7877
# Epoch 294/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1117 - dice_coef: 0.8948 - iou: 0.8110 - val_loss: 0.1407 - val_dice_coef: 0.8722 - val_iou: 0.7791
# Epoch 295/300
# 80/80 [==============================] - 3s 37ms/step - loss: 0.1045 - dice_coef: 0.9012 - iou: 0.8212 - val_loss: 0.1179 - val_dice_coef: 0.8901 - val_iou: 0.8052
# Epoch 296/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1040 - dice_coef: 0.9016 - iou: 0.8222 - val_loss: 0.1387 - val_dice_coef: 0.8731 - val_iou: 0.7806
# Epoch 297/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1038 - dice_coef: 0.9018 - iou: 0.8227 - val_loss: 0.1116 - val_dice_coef: 0.8953 - val_iou: 0.8132
# Epoch 298/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1030 - dice_coef: 0.9026 - iou: 0.8241 - val_loss: 0.1201 - val_dice_coef: 0.8876 - val_iou: 0.8002
# Epoch 299/300
# 80/80 [==============================] - 3s 34ms/step - loss: 0.1067 - dice_coef: 0.8992 - iou: 0.8179 - val_loss: 0.1439 - val_dice_coef: 0.8689 - val_iou: 0.7740
# Epoch 300/300
# 80/80 [==============================] - 3s 35ms/step - loss: 0.1022 - dice_coef: 0.9033 - iou: 0.8253 - val_loss: 0.1127 - val_dice_coef: 0.8936 - val_iou: 0.8081

# %%
best_epoch = np.argmin(history.history["val_loss"])
print("Best Validation Loss: ", history.history["val_loss"][best_epoch])
print("Best Dice Coffecient (F1): ", history.history["val_dice_coef"][best_epoch])
print("Best IoU (Jaccard): ", history.history["val_iou"][best_epoch])
# Out:
# Best Validation Loss:  0.10298384726047516
# Best Dice Coffecient (F1):  0.9024373292922974
# Best IoU (Jaccard):  0.8229774236679077

# %%
t_loss = history.history['loss']
val_loss = history.history['val_loss']
acc=history.history['dice_coef']
epochs = range(1, len(acc) + 1)
plt.figure(figsize=(8, 8))
plt.plot(epochs, t_loss, 'orange', label='Train Loss')
plt.plot(epochs, val_loss, 'y', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Log Dice Loss')
# plt.grid()
plt.legend()

# %%
loss = history.history['loss']
acc=history.history['dice_coef']
val_acc=history.history['val_dice_coef']
epochs = range(1, len(acc) + 1)
plt.figure(figsize=(8, 8))
plt.plot(epochs, acc, 'c', label='Train')
plt.plot(epochs, val_acc, 'b', label='Validation')
plt.title('Training and Validation Dice')
plt.xlabel('Epochs')
plt.ylabel('Dice Coef')
# plt.grid()
plt.legend()

# %%
from skimage.morphology import dilation
from skimage.feature import canny
from skimage import color

# %%
for image , mask, file_name in zip(X_test[: 10], Y_test[:10], name_test[:10]):

    x_test = image.copy()
    x_test = tf.image.resize(x_test, (128, 128))/122.5 - 1.0

    mask = (mask[:, :, 0] > 225.5) + 0.0
    

    pred = (model.predict(tf.expand_dims(x_test, axis=0), verbose=0)[0] > 0.5).astype(float)
    pred = cv2.resize(pred, (256, 256))

    fig = plt.figure(figsize=(10, 4))
    ax = fig.add_subplot(1, 3, 1)
    ax.set_title('Predicted')
    edgesp = canny(pred)
    edgesp = 1.0-dilation(edgesp)
    edgesp = color.gray2rgb(1.0*edgesp)
    ax.imshow((image*edgesp).astype(int)[:, :, ::-1])


    ax = fig.add_subplot(1, 3, 2)
    ax.set_title('Correct')
    edgesc = canny(mask)
    edgesc = 1.0-dilation(edgesc)
    edgesc = color.gray2rgb(1.0*edgesc)
    ax.imshow((image*edgesc).astype(int)[:, :, ::-1])

    ax = fig.add_subplot(1, 3, 3)
    ax.set_title('Image')
    ax.imshow(image[:, :, ::-1])

# %%
for image , mask, file_name in zip(X_test[: 10], Y_test[:10], name_test[:10]):

    x_test = image.copy()
    x_test = tf.image.resize(x_test, (128, 128))/122.5 - 1.0

    mask = (mask[:, :, 0] > 225.5) + 0.0
    

    pred = (model.predict(tf.expand_dims(x_test, axis=0), verbose=0)[0] > 0.5).astype(float)
    pred = cv2.resize(pred, (256, 256))

    fig = plt.figure(figsize=(10, 4))
    ax = fig.add_subplot(1, 3, 1)
    ax.set_title('Predicted')
#     edgesp = canny(pred)
#     edgesp = 1.0-dilation(edgesp)
#     edgesp = color.gray2rgb(1.0*edgesp)
    ax.imshow(pred)


    ax = fig.add_subplot(1, 3, 2)
    ax.set_title('Correct')
#     edgesc = canny(mask)
#     edgesc = 1.0-dilation(edgesc)
#     edgesc = color.gray2rgb(1.0*edgesc)
    ax.imshow(mask)

    ax = fig.add_subplot(1, 3, 3)
    ax.set_title('Image')
    ax.imshow(image[:, :, ::-1])
