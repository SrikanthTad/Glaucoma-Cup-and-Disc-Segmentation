# %%
import cv2
import tensorflow as tf
import numpy as np
import os
import matplotlib.pyplot as plt
# Out:
# 2023-04-24 17:09:56.407710: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-24 17:09:56.475065: I tensorflow/core/util/port.cc:104] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
IMAGE_DIR = "/data2/SrikanthData/ResearchWork2/tensorflow/Project/img_data/d2/Dataset/MainImages"
MASK_DIR = "/data2/SrikanthData/ResearchWork2/tensorflow/Project/img_data/d2/Dataset/Cropped_cup"
BATCH_SIZE = 4

# %%
def double_conv_block(x, n_filters):
    # Conv2D then ReLU activation
    x = tf.keras.layers.Conv2D(
        n_filters,
        3,
        padding="same",
        activation="relu",
        kernel_initializer="he_normal"
    )(x)
    # Conv2D then ReLU activation
    x = tf.keras.layers.Conv2D(
        n_filters,
        3,
        padding="same",
        activation="relu",
        kernel_initializer="he_normal"
    )(x)
    return x

def downsample_block(x, n_filters):
    f = double_conv_block(x, n_filters)
    p = tf.keras.layers.MaxPool2D(2)(f)
    p = tf.keras.layers.Dropout(0.3)(p)
    return f, p

def upsample_block(x, conv_features, n_filters):
    # upsample
    x = tf.keras.layers.Conv2DTranspose(n_filters, 3, 2, padding="same")(x)
    # concatenate
    x = tf.keras.layers.concatenate([x, conv_features])
    # dropout
    x = tf.keras.layers.Dropout(0.3)(x)
    # Conv2D twice with ReLU activation
    x = double_conv_block(x, n_filters)
    return x

def create_unet():
    # inputs
    inputs = tf.keras.layers.Input(shape=(128,128,3))
    # encoder: contracting path - downsample
    # 1 - downsample
    f1, p1 = downsample_block(inputs, 32) # 64
    # 2 - downsample
    f2, p2 = downsample_block(p1, 64) # 128
    # 3 - downsample
    f3, p3 = downsample_block(p2, 128) # 256
    # 4 - downsample
    f4, p4 = downsample_block(p3, 256) # 512
    # 5 - bottleneck
    bottleneck = double_conv_block(p4, 256) # 1024

    # decoder: expanding path - upsample
    # 6 - upsample
    u6 = upsample_block(bottleneck, f4, 256) # 512
    # 7 - upsample
    u7 = upsample_block(u6, f3, 128) # 256
    # 8 - upsample
    u8 = upsample_block(u7, f2, 64) # 128
    # 9 - upsample
    u9 = upsample_block(u8, f1, 32)
    # outputs
    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation = "sigmoid")(u9)
    # unet model with Keras Functional API
    unet_model = tf.keras.Model(inputs, outputs, name="U-Net")
    return unet_model

# %%
# load data
assert len(os.listdir(IMAGE_DIR)) == len(os.listdir(MASK_DIR)), "Different number of images and masks"
X, Y, file_names = [], [], []
for image_name in sorted(os.listdir(IMAGE_DIR)):
    mask_name = image_name
    

    image = cv2.imread(os.path.join(IMAGE_DIR, image_name))
    image = cv2.resize(image, (256, 256))
    

    mask = cv2.imread(os.path.join(MASK_DIR, mask_name))
    mask = cv2.resize(mask, (256, 256))


    X.append(image)
    Y.append(mask)
    file_names.append(image_name)

# %%
def dice_coef(y_true, y_pred): # accuracy function 
    y_true_f = tf.reshape(y_true, [-1])
    y_pred_f = tf.reshape(y_pred, [-1])
    intersection = tf.reduce_sum(y_true_f * y_pred_f)
    return (2. * intersection + 1e-6) / (tf.reduce_sum(y_true_f) + tf.reduce_sum(y_pred_f) + 1e-6)
  
def dice_loss(y_true,y_pred): # loss function 
    return -dice_coef(y_true,y_pred)
  
def log_dice_loss(y_true, y_pred):
    return -tf.math.log(dice_coef(y_true, y_pred))



def iou(y_true, y_pred, threshold=0.5):                                                             
    y_true = tf.reshape(y_true, [-1])                                                               
    y_true = tf.cast(y_true, tf.float32)                                                            
    y_pred = tf.cast(y_pred > threshold, tf.float32)                                                
                                                                                                    
    y_pred = tf.reshape(y_pred, [-1])                                                               
                                                                                                    
                                                                                                    
    intersection = tf.reduce_sum(y_true*y_pred)                                                     
    union = tf.reduce_sum(tf.cast(y_true + y_pred > 0, tf.float32))                                 
                                                                                                    
    return intersection/union

# %%
def augmentation_fn(image, mask, training=True):
    """
    Augmentation for training set only. random cropy 50% of the time, random flip 50% of the time
    """
    # change brightness

    image = image.copy()
    mask = mask.copy()
    if training:
        image = tf.image.random_brightness(image, 0.1)
        image = tf.image.random_hue(image, 0.1)
    
        seed = np.random.randint(0, 1000, (2, ))
        if np.random.rand() < 0.5:
            random_size = np.random.randint(210, 256) # this is because the size of the image is 256 
        
            image = tf.image.stateless_random_crop(image, [random_size, random_size, 3], seed=seed)
            mask = tf.image.stateless_random_crop(mask, [random_size, random_size, 3], seed=seed)

        if np.random.rand() < 0.5:
            image = tf.image.stateless_random_flip_up_down(image, seed)
            mask = tf.image.stateless_random_flip_up_down(mask, seed)


    image = tf.image.resize(image, (128, 128))/122.5 - 1.0
    mask = tf.cast(tf.image.resize(mask, (128, 128)) > 122.5, float)[:, :, :1]
    
    return image, mask

# %%
# Split train and test
mask = list(range(len(X)))
np.random.seed(0)
np.random.shuffle(mask)
n_train = int(0.8*len(mask))
X_train = [X[i] for i in mask[:n_train]]
Y_train = [Y[i] for i in mask[:n_train]]
name_train = [file_names[i] for i in mask[:n_train]]

X_test = [X[i] for i in mask[n_train:]]
Y_test = [Y[i] for i in mask[n_train:]]
name_test = [file_names[i] for i in mask[n_train:]]

def data_generator(X, Y, batch_size=BATCH_SIZE, training=True):
    n_data = len(X)

    i = 0
    while True:
        if i + batch_size > n_data:
            i = 0
            mask = np.arange(n_data)
            np.random.shuffle(mask)

            X = [X[j] for j in mask]
            Y = [Y[j] for j in mask]
        
        mini_X = X[i: i + batch_size] 
        mini_Y = Y[i: i + batch_size]

        
        processed_data = [augmentation_fn(x, y, training) for x, y in zip(mini_X, mini_Y)]
        mini_X = [item[0] for item in processed_data]
        mini_Y = [item[1] for item in processed_data]


        mini_X = tf.concat([tf.expand_dims(_, axis=0) for _ in mini_X], axis=0)
        mini_Y = tf.concat([tf.expand_dims(_, axis=0) for _ in mini_Y], axis=0)

        i += batch_size
        yield mini_X, mini_Y

# %%
model = create_unet()

model.summary()
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=log_dice_loss,
    metrics=[dice_coef, iou]
)

train_generator = data_generator(X_train, Y_train, training=True)
validation_generator = data_generator(X_test, Y_test, training=False)

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=100, restore_best_weights=True)
history = model.fit(
    train_generator,
    epochs=300,
    validation_data=validation_generator,
    steps_per_epoch=len(X_train)//BATCH_SIZE,
    validation_steps=len(X_test)//BATCH_SIZE,
    callbacks=[early_stopping]
)
# Out:
# 2023-04-24 17:10:01.580656: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22288 MB memory:  -> device: 0, name: GeForce RTX 3090, pci bus id: 0000:1b:00.0, compute capability: 8.6
# 2023-04-24 17:10:01.582412: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 20509 MB memory:  -> device: 1, name: GeForce RTX 3090, pci bus id: 0000:3e:00.0, compute capability: 8.6
# 2023-04-24 17:10:01.583447: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 15314 MB memory:  -> device: 2, name: GeForce RTX 3090, pci bus id: 0000:89:00.0, compute capability: 8.6
# 2023-04-24 17:10:01.584858: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1613] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 22288 MB memory:  -> device: 3, name: GeForce RTX 3090, pci bus id: 0000:b2:00.0, compute capability: 8.6
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 32  896         ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 32  9248        ['conv2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 32)   0           ['conv2d_1[0][0]']
#
#  dropout (Dropout)              (None, 64, 64, 32)   0           ['max_pooling2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 64)   18496       ['dropout[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 64)   36928       ['conv2d_2[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 64)  0           ['conv2d_3[0][0]']
#
#  dropout_1 (Dropout)            (None, 32, 32, 64)   0           ['max_pooling2d_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 128)  73856       ['dropout_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 128)  147584      ['conv2d_4[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 128)  0          ['conv2d_5[0][0]']
#
#  dropout_2 (Dropout)            (None, 16, 16, 128)  0           ['max_pooling2d_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 256)  295168      ['dropout_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 256)  590080      ['conv2d_6[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 256)   0           ['conv2d_7[0][0]']
#
#  dropout_3 (Dropout)            (None, 8, 8, 256)    0           ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    590080      ['dropout_3[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 256)    590080      ['conv2d_8[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 256)  590080     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  dropout_4 (Dropout)            (None, 16, 16, 512)  0           ['concatenate[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 256)  1179904     ['dropout_4[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 256)  590080      ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 128)  295040     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 256)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  dropout_5 (Dropout)            (None, 32, 32, 256)  0           ['concatenate_1[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 32, 32, 128)  295040      ['dropout_5[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 32, 32, 128)  147584      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 64)  73792       ['conv2d_13[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 128)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 128)  0           ['concatenate_2[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 64)   73792       ['dropout_6[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 64, 64, 64)   36928       ['conv2d_14[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 32  18464      ['conv2d_15[0][0]']
#  spose)                         )
#  concatenate_3 (Concatenate)    (None, 128, 128, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  dropout_7 (Dropout)            (None, 128, 128, 64  0           ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 32  18464       ['dropout_7[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 128, 128, 32  9248        ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 128, 128, 1)  33          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 5,680,865
# Trainable params: 5,680,865
# Non-trainable params: 0
# __________________________________________________________________________________________________
# Epoch 1/300
# 2023-04-24 17:10:04.182685: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inU-Net/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-04-24 17:10:05.626842: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:428] Loaded cuDNN version 8401
# 2023-04-24 17:10:07.580917: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:630] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 14/14 [==============================] - 10s 64ms/step - loss: 2.6500 - dice_coef: 0.0796 - iou: 0.0712 - val_loss: 2.1925 - val_dice_coef: 0.1175 - val_iou: 0.0579
# Epoch 2/300
# 14/14 [==============================] - 1s 42ms/step - loss: 1.4815 - dice_coef: 0.2637 - iou: 0.2268 - val_loss: 1.1806 - val_dice_coef: 0.3138 - val_iou: 0.2141
# Epoch 3/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.9569 - dice_coef: 0.4033 - iou: 0.2981 - val_loss: 1.8748 - val_dice_coef: 0.1928 - val_iou: 0.1135
# Epoch 4/300
# 14/14 [==============================] - 1s 39ms/step - loss: 1.0350 - dice_coef: 0.4131 - iou: 0.2984 - val_loss: 3.5161 - val_dice_coef: 0.2864 - val_iou: 0.1963
# Epoch 5/300
# 14/14 [==============================] - 1s 40ms/step - loss: 1.1676 - dice_coef: 0.3387 - iou: 0.2208 - val_loss: 1.1312 - val_dice_coef: 0.3388 - val_iou: 0.2212
# Epoch 6/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.9797 - dice_coef: 0.4226 - iou: 0.2909 - val_loss: 0.6911 - val_dice_coef: 0.5484 - val_iou: 0.4153
# Epoch 7/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.8796 - dice_coef: 0.4316 - iou: 0.2889 - val_loss: 0.8495 - val_dice_coef: 0.4283 - val_iou: 0.2986
# Epoch 8/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.8181 - dice_coef: 0.4727 - iou: 0.3290 - val_loss: 0.8173 - val_dice_coef: 0.4451 - val_iou: 0.3046
# Epoch 9/300
# 14/14 [==============================] - 1s 42ms/step - loss: 0.6877 - dice_coef: 0.5190 - iou: 0.3713 - val_loss: 0.4982 - val_dice_coef: 0.6207 - val_iou: 0.4710
# Epoch 10/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.6415 - dice_coef: 0.5372 - iou: 0.3822 - val_loss: 0.5038 - val_dice_coef: 0.6064 - val_iou: 0.4495
# Epoch 11/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.6204 - dice_coef: 0.5534 - iou: 0.3973 - val_loss: 0.5436 - val_dice_coef: 0.5936 - val_iou: 0.4383
# Epoch 12/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.6701 - dice_coef: 0.5284 - iou: 0.3780 - val_loss: 0.5960 - val_dice_coef: 0.5575 - val_iou: 0.4004
# Epoch 13/300
# 14/14 [==============================] - 1s 41ms/step - loss: 0.7133 - dice_coef: 0.5495 - iou: 0.4115 - val_loss: 0.4979 - val_dice_coef: 0.6115 - val_iou: 0.4518
# Epoch 14/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.6340 - dice_coef: 0.5427 - iou: 0.3849 - val_loss: 0.7696 - val_dice_coef: 0.4655 - val_iou: 0.3217
# Epoch 15/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.6089 - dice_coef: 0.5727 - iou: 0.4267 - val_loss: 0.5590 - val_dice_coef: 0.5738 - val_iou: 0.4085
# Epoch 16/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.7204 - dice_coef: 0.5170 - iou: 0.3663 - val_loss: 0.7912 - val_dice_coef: 0.4638 - val_iou: 0.3105
# Epoch 17/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.9560 - dice_coef: 0.4459 - iou: 0.3078 - val_loss: 0.9139 - val_dice_coef: 0.4175 - val_iou: 0.2724
# Epoch 18/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.9062 - dice_coef: 0.4438 - iou: 0.3042 - val_loss: 1.2669 - val_dice_coef: 0.3360 - val_iou: 0.2160
# Epoch 19/300
# 14/14 [==============================] - 1s 41ms/step - loss: 0.8505 - dice_coef: 0.4439 - iou: 0.3010 - val_loss: 0.4379 - val_dice_coef: 0.6481 - val_iou: 0.4867
# Epoch 20/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.5556 - dice_coef: 0.5874 - iou: 0.4279 - val_loss: 0.5262 - val_dice_coef: 0.6267 - val_iou: 0.4881
# Epoch 21/300
# 14/14 [==============================] - 1s 41ms/step - loss: 0.6075 - dice_coef: 0.5709 - iou: 0.4233 - val_loss: 0.5396 - val_dice_coef: 0.5862 - val_iou: 0.4198
# Epoch 22/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.6024 - dice_coef: 0.5623 - iou: 0.4041 - val_loss: 0.4908 - val_dice_coef: 0.6244 - val_iou: 0.4649
# Epoch 23/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.4295 - dice_coef: 0.6645 - iou: 0.5135 - val_loss: 0.4799 - val_dice_coef: 0.6211 - val_iou: 0.4516
# Epoch 24/300
# 14/14 [==============================] - 1s 41ms/step - loss: 0.5212 - dice_coef: 0.6061 - iou: 0.4461 - val_loss: 0.4019 - val_dice_coef: 0.6738 - val_iou: 0.5142
# Epoch 25/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.4251 - dice_coef: 0.6572 - iou: 0.4965 - val_loss: 0.4719 - val_dice_coef: 0.6244 - val_iou: 0.4545
# Epoch 26/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.4537 - dice_coef: 0.6441 - iou: 0.4861 - val_loss: 0.5512 - val_dice_coef: 0.5862 - val_iou: 0.4250
# Epoch 27/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.4486 - dice_coef: 0.6497 - iou: 0.4979 - val_loss: 0.5036 - val_dice_coef: 0.6075 - val_iou: 0.4396
# Epoch 28/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.4740 - dice_coef: 0.6317 - iou: 0.4739 - val_loss: 0.5759 - val_dice_coef: 0.5679 - val_iou: 0.4004
# Epoch 29/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.5333 - dice_coef: 0.5994 - iou: 0.4376 - val_loss: 0.7882 - val_dice_coef: 0.4616 - val_iou: 0.3033
# Epoch 30/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.4416 - dice_coef: 0.6490 - iou: 0.4874 - val_loss: 0.5499 - val_dice_coef: 0.5794 - val_iou: 0.4096
# Epoch 31/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.4199 - dice_coef: 0.6674 - iou: 0.5116 - val_loss: 0.4732 - val_dice_coef: 0.6241 - val_iou: 0.4546
# Epoch 32/300
# 14/14 [==============================] - 1s 41ms/step - loss: 0.4833 - dice_coef: 0.6299 - iou: 0.4747 - val_loss: 0.5034 - val_dice_coef: 0.6047 - val_iou: 0.4336
# Epoch 33/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3555 - dice_coef: 0.7036 - iou: 0.5472 - val_loss: 0.5546 - val_dice_coef: 0.5752 - val_iou: 0.4062
# Epoch 34/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3990 - dice_coef: 0.6749 - iou: 0.5144 - val_loss: 0.5909 - val_dice_coef: 0.5616 - val_iou: 0.3964
# Epoch 35/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3559 - dice_coef: 0.7040 - iou: 0.5523 - val_loss: 0.4932 - val_dice_coef: 0.6148 - val_iou: 0.4476
# Epoch 36/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.4091 - dice_coef: 0.6681 - iou: 0.5069 - val_loss: 0.4285 - val_dice_coef: 0.6565 - val_iou: 0.4950
# Epoch 37/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3955 - dice_coef: 0.6809 - iou: 0.5268 - val_loss: 0.5447 - val_dice_coef: 0.5804 - val_iou: 0.4104
# Epoch 38/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3814 - dice_coef: 0.6869 - iou: 0.5288 - val_loss: 0.4707 - val_dice_coef: 0.6302 - val_iou: 0.4683
# Epoch 39/300
# 14/14 [==============================] - 0s 36ms/step - loss: 0.3827 - dice_coef: 0.6866 - iou: 0.5295 - val_loss: 0.4588 - val_dice_coef: 0.6341 - val_iou: 0.4659
# Epoch 40/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3676 - dice_coef: 0.7002 - iou: 0.5477 - val_loss: 0.6143 - val_dice_coef: 0.5437 - val_iou: 0.3741
# Epoch 41/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.3874 - dice_coef: 0.6865 - iou: 0.5313 - val_loss: 0.5112 - val_dice_coef: 0.6002 - val_iou: 0.4301
# Epoch 42/300
# 14/14 [==============================] - 1s 41ms/step - loss: 0.3847 - dice_coef: 0.6854 - iou: 0.5281 - val_loss: 0.6094 - val_dice_coef: 0.5457 - val_iou: 0.3794
# Epoch 43/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.4773 - dice_coef: 0.6418 - iou: 0.4871 - val_loss: 0.5551 - val_dice_coef: 0.5846 - val_iou: 0.4228
# Epoch 44/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3349 - dice_coef: 0.7203 - iou: 0.5697 - val_loss: 0.5523 - val_dice_coef: 0.5829 - val_iou: 0.4159
# Epoch 45/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3382 - dice_coef: 0.7171 - iou: 0.5656 - val_loss: 0.5947 - val_dice_coef: 0.5549 - val_iou: 0.3887
# Epoch 46/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3638 - dice_coef: 0.6979 - iou: 0.5421 - val_loss: 0.5467 - val_dice_coef: 0.5802 - val_iou: 0.4098
# Epoch 47/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3970 - dice_coef: 0.6833 - iou: 0.5330 - val_loss: 0.4842 - val_dice_coef: 0.6308 - val_iou: 0.4741
# Epoch 48/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3508 - dice_coef: 0.7072 - iou: 0.5515 - val_loss: 0.4720 - val_dice_coef: 0.6303 - val_iou: 0.4672
# Epoch 49/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.4298 - dice_coef: 0.6629 - iou: 0.5052 - val_loss: 0.4962 - val_dice_coef: 0.6131 - val_iou: 0.4484
# Epoch 50/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3431 - dice_coef: 0.7119 - iou: 0.5566 - val_loss: 0.4632 - val_dice_coef: 0.6327 - val_iou: 0.4690
# Epoch 51/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3876 - dice_coef: 0.6840 - iou: 0.5267 - val_loss: 0.5259 - val_dice_coef: 0.6039 - val_iou: 0.4454
# Epoch 52/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.3431 - dice_coef: 0.7144 - iou: 0.5633 - val_loss: 0.5997 - val_dice_coef: 0.5522 - val_iou: 0.3855
# Epoch 53/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3712 - dice_coef: 0.6980 - iou: 0.5458 - val_loss: 0.4147 - val_dice_coef: 0.6623 - val_iou: 0.4965
# Epoch 54/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3402 - dice_coef: 0.7152 - iou: 0.5613 - val_loss: 0.5829 - val_dice_coef: 0.5792 - val_iou: 0.4281
# Epoch 55/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3520 - dice_coef: 0.7088 - iou: 0.5557 - val_loss: 0.6164 - val_dice_coef: 0.5546 - val_iou: 0.3942
# Epoch 56/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3287 - dice_coef: 0.7235 - iou: 0.5730 - val_loss: 0.5023 - val_dice_coef: 0.6212 - val_iou: 0.4667
# Epoch 57/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.3473 - dice_coef: 0.7085 - iou: 0.5510 - val_loss: 0.5276 - val_dice_coef: 0.5953 - val_iou: 0.4283
# Epoch 58/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3310 - dice_coef: 0.7210 - iou: 0.5692 - val_loss: 0.4609 - val_dice_coef: 0.6319 - val_iou: 0.4625
# Epoch 59/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3457 - dice_coef: 0.7132 - iou: 0.5616 - val_loss: 0.5687 - val_dice_coef: 0.5698 - val_iou: 0.4037
# Epoch 60/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3467 - dice_coef: 0.7104 - iou: 0.5564 - val_loss: 0.6982 - val_dice_coef: 0.5205 - val_iou: 0.3656
# Epoch 61/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3328 - dice_coef: 0.7216 - iou: 0.5720 - val_loss: 0.5421 - val_dice_coef: 0.5894 - val_iou: 0.4243
# Epoch 62/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3362 - dice_coef: 0.7171 - iou: 0.5631 - val_loss: 0.6355 - val_dice_coef: 0.5376 - val_iou: 0.3731
# Epoch 63/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3537 - dice_coef: 0.7089 - iou: 0.5586 - val_loss: 0.4829 - val_dice_coef: 0.6184 - val_iou: 0.4499
# Epoch 64/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3345 - dice_coef: 0.7197 - iou: 0.5683 - val_loss: 0.4647 - val_dice_coef: 0.6288 - val_iou: 0.4583
# Epoch 65/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3346 - dice_coef: 0.7184 - iou: 0.5651 - val_loss: 0.5095 - val_dice_coef: 0.6037 - val_iou: 0.4366
# Epoch 66/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3556 - dice_coef: 0.7069 - iou: 0.5550 - val_loss: 0.4819 - val_dice_coef: 0.6180 - val_iou: 0.4474
# Epoch 67/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3233 - dice_coef: 0.7261 - iou: 0.5737 - val_loss: 0.5499 - val_dice_coef: 0.5792 - val_iou: 0.4114
# Epoch 68/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3484 - dice_coef: 0.7088 - iou: 0.5533 - val_loss: 0.5577 - val_dice_coef: 0.5735 - val_iou: 0.4033
# Epoch 69/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3290 - dice_coef: 0.7244 - iou: 0.5744 - val_loss: 0.6371 - val_dice_coef: 0.5344 - val_iou: 0.3696
# Epoch 70/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3607 - dice_coef: 0.7029 - iou: 0.5491 - val_loss: 0.5671 - val_dice_coef: 0.5726 - val_iou: 0.4054
# Epoch 71/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3130 - dice_coef: 0.7334 - iou: 0.5832 - val_loss: 0.4980 - val_dice_coef: 0.6094 - val_iou: 0.4409
# Epoch 72/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2961 - dice_coef: 0.7454 - iou: 0.5977 - val_loss: 0.4954 - val_dice_coef: 0.6119 - val_iou: 0.4455
# Epoch 73/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3269 - dice_coef: 0.7235 - iou: 0.5704 - val_loss: 0.5905 - val_dice_coef: 0.5699 - val_iou: 0.4092
# Epoch 74/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3486 - dice_coef: 0.7144 - iou: 0.5669 - val_loss: 0.6060 - val_dice_coef: 0.5570 - val_iou: 0.3972
# Epoch 75/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3640 - dice_coef: 0.7020 - iou: 0.5495 - val_loss: 0.5061 - val_dice_coef: 0.6056 - val_iou: 0.4377
# Epoch 76/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.3573 - dice_coef: 0.7037 - iou: 0.5491 - val_loss: 0.4551 - val_dice_coef: 0.6353 - val_iou: 0.4675
# Epoch 77/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3221 - dice_coef: 0.7321 - iou: 0.5872 - val_loss: 0.4060 - val_dice_coef: 0.6666 - val_iou: 0.5019
# Epoch 78/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3080 - dice_coef: 0.7383 - iou: 0.5910 - val_loss: 0.4700 - val_dice_coef: 0.6279 - val_iou: 0.4590
# Epoch 79/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3005 - dice_coef: 0.7423 - iou: 0.5939 - val_loss: 0.4763 - val_dice_coef: 0.6215 - val_iou: 0.4514
# Epoch 80/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3087 - dice_coef: 0.7377 - iou: 0.5901 - val_loss: 0.5938 - val_dice_coef: 0.5596 - val_iou: 0.3939
# Epoch 81/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.3211 - dice_coef: 0.7338 - iou: 0.5902 - val_loss: 0.6117 - val_dice_coef: 0.5432 - val_iou: 0.3738
# Epoch 82/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2996 - dice_coef: 0.7425 - iou: 0.5934 - val_loss: 0.4518 - val_dice_coef: 0.6367 - val_iou: 0.4666
# Epoch 83/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.3015 - dice_coef: 0.7429 - iou: 0.5972 - val_loss: 0.5631 - val_dice_coef: 0.5713 - val_iou: 0.4013
# Epoch 84/300
# 14/14 [==============================] - 0s 38ms/step - loss: 0.2963 - dice_coef: 0.7480 - iou: 0.6041 - val_loss: 0.5209 - val_dice_coef: 0.5976 - val_iou: 0.4286
# Epoch 85/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3216 - dice_coef: 0.7293 - iou: 0.5804 - val_loss: 0.4993 - val_dice_coef: 0.6091 - val_iou: 0.4411
# Epoch 86/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3129 - dice_coef: 0.7341 - iou: 0.5848 - val_loss: 0.4802 - val_dice_coef: 0.6222 - val_iou: 0.4569
# Epoch 87/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3514 - dice_coef: 0.7090 - iou: 0.5552 - val_loss: 0.4272 - val_dice_coef: 0.6534 - val_iou: 0.4864
# Epoch 88/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3425 - dice_coef: 0.7135 - iou: 0.5593 - val_loss: 0.5482 - val_dice_coef: 0.5811 - val_iou: 0.4133
# Epoch 89/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3339 - dice_coef: 0.7255 - iou: 0.5789 - val_loss: 0.7248 - val_dice_coef: 0.4997 - val_iou: 0.3420
# Epoch 90/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3439 - dice_coef: 0.7143 - iou: 0.5620 - val_loss: 0.5112 - val_dice_coef: 0.6037 - val_iou: 0.4375
# Epoch 91/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3238 - dice_coef: 0.7253 - iou: 0.5723 - val_loss: 0.4679 - val_dice_coef: 0.6315 - val_iou: 0.4677
# Epoch 92/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3101 - dice_coef: 0.7352 - iou: 0.5842 - val_loss: 0.4008 - val_dice_coef: 0.6722 - val_iou: 0.5102
# Epoch 93/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3219 - dice_coef: 0.7289 - iou: 0.5791 - val_loss: 0.5233 - val_dice_coef: 0.5936 - val_iou: 0.4234
# Epoch 94/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2977 - dice_coef: 0.7451 - iou: 0.5979 - val_loss: 0.5492 - val_dice_coef: 0.5821 - val_iou: 0.4155
# Epoch 95/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3254 - dice_coef: 0.7286 - iou: 0.5824 - val_loss: 0.5241 - val_dice_coef: 0.5926 - val_iou: 0.4216
# Epoch 96/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3188 - dice_coef: 0.7312 - iou: 0.5826 - val_loss: 0.6363 - val_dice_coef: 0.5338 - val_iou: 0.3693
# Epoch 97/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3473 - dice_coef: 0.7126 - iou: 0.5604 - val_loss: 0.6093 - val_dice_coef: 0.5471 - val_iou: 0.3798
# Epoch 98/300
# 14/14 [==============================] - 0s 36ms/step - loss: 0.2667 - dice_coef: 0.7677 - iou: 0.6271 - val_loss: 0.4975 - val_dice_coef: 0.6086 - val_iou: 0.4395
# Epoch 99/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3193 - dice_coef: 0.7288 - iou: 0.5778 - val_loss: 0.5480 - val_dice_coef: 0.5781 - val_iou: 0.4063
# Epoch 100/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3233 - dice_coef: 0.7264 - iou: 0.5742 - val_loss: 0.5224 - val_dice_coef: 0.6063 - val_iou: 0.4471
# Epoch 101/300
# 14/14 [==============================] - 0s 38ms/step - loss: 0.2641 - dice_coef: 0.7690 - iou: 0.6267 - val_loss: 0.4951 - val_dice_coef: 0.6136 - val_iou: 0.4475
# Epoch 102/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3006 - dice_coef: 0.7441 - iou: 0.5986 - val_loss: 0.4668 - val_dice_coef: 0.6285 - val_iou: 0.4611
# Epoch 103/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3222 - dice_coef: 0.7346 - iou: 0.5919 - val_loss: 0.4594 - val_dice_coef: 0.6334 - val_iou: 0.4649
# Epoch 104/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3387 - dice_coef: 0.7180 - iou: 0.5672 - val_loss: 0.6619 - val_dice_coef: 0.5204 - val_iou: 0.3551
# Epoch 105/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2901 - dice_coef: 0.7532 - iou: 0.6118 - val_loss: 0.4745 - val_dice_coef: 0.6264 - val_iou: 0.4604
# Epoch 106/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2952 - dice_coef: 0.7487 - iou: 0.6057 - val_loss: 0.4642 - val_dice_coef: 0.6291 - val_iou: 0.4598
# Epoch 107/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2958 - dice_coef: 0.7473 - iou: 0.6021 - val_loss: 0.4948 - val_dice_coef: 0.6124 - val_iou: 0.4448
# Epoch 108/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2824 - dice_coef: 0.7577 - iou: 0.6156 - val_loss: 0.5190 - val_dice_coef: 0.5961 - val_iou: 0.4273
# Epoch 109/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3073 - dice_coef: 0.7381 - iou: 0.5892 - val_loss: 0.4496 - val_dice_coef: 0.6389 - val_iou: 0.4708
# Epoch 110/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2908 - dice_coef: 0.7509 - iou: 0.6063 - val_loss: 0.5386 - val_dice_coef: 0.5893 - val_iou: 0.4250
# Epoch 111/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2716 - dice_coef: 0.7631 - iou: 0.6193 - val_loss: 0.4744 - val_dice_coef: 0.6236 - val_iou: 0.4556
# Epoch 112/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2805 - dice_coef: 0.7586 - iou: 0.6160 - val_loss: 0.5666 - val_dice_coef: 0.5783 - val_iou: 0.4173
# Epoch 113/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2893 - dice_coef: 0.7516 - iou: 0.6065 - val_loss: 0.6532 - val_dice_coef: 0.5268 - val_iou: 0.3634
# Epoch 114/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3052 - dice_coef: 0.7419 - iou: 0.5969 - val_loss: 0.5526 - val_dice_coef: 0.5822 - val_iou: 0.4163
# Epoch 115/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2835 - dice_coef: 0.7550 - iou: 0.6100 - val_loss: 0.4533 - val_dice_coef: 0.6377 - val_iou: 0.4711
# Epoch 116/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2975 - dice_coef: 0.7454 - iou: 0.5985 - val_loss: 0.5414 - val_dice_coef: 0.5833 - val_iou: 0.4139
# Epoch 117/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2815 - dice_coef: 0.7577 - iou: 0.6162 - val_loss: 0.5619 - val_dice_coef: 0.5756 - val_iou: 0.4103
# Epoch 118/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2938 - dice_coef: 0.7501 - iou: 0.6074 - val_loss: 0.4872 - val_dice_coef: 0.6151 - val_iou: 0.4464
# Epoch 119/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2815 - dice_coef: 0.7578 - iou: 0.6153 - val_loss: 0.3966 - val_dice_coef: 0.6736 - val_iou: 0.5107
# Epoch 120/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3026 - dice_coef: 0.7453 - iou: 0.6032 - val_loss: 0.4746 - val_dice_coef: 0.6222 - val_iou: 0.4536
# Epoch 121/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2862 - dice_coef: 0.7533 - iou: 0.6086 - val_loss: 0.4178 - val_dice_coef: 0.6636 - val_iou: 0.5017
# Epoch 122/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2836 - dice_coef: 0.7572 - iou: 0.6155 - val_loss: 0.5590 - val_dice_coef: 0.5731 - val_iou: 0.4036
# Epoch 123/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2730 - dice_coef: 0.7627 - iou: 0.6200 - val_loss: 0.4327 - val_dice_coef: 0.6494 - val_iou: 0.4844
# Epoch 124/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2796 - dice_coef: 0.7583 - iou: 0.6146 - val_loss: 0.4465 - val_dice_coef: 0.6437 - val_iou: 0.4785
# Epoch 125/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2768 - dice_coef: 0.7641 - iou: 0.6268 - val_loss: 0.5435 - val_dice_coef: 0.5845 - val_iou: 0.4185
# Epoch 126/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2725 - dice_coef: 0.7646 - iou: 0.6248 - val_loss: 0.3827 - val_dice_coef: 0.6849 - val_iou: 0.5250
# Epoch 127/300
# 14/14 [==============================] - 1s 41ms/step - loss: 0.2838 - dice_coef: 0.7552 - iou: 0.6104 - val_loss: 0.5735 - val_dice_coef: 0.5752 - val_iou: 0.4140
# Epoch 128/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.3240 - dice_coef: 0.7296 - iou: 0.5819 - val_loss: 0.5094 - val_dice_coef: 0.6026 - val_iou: 0.4345
# Epoch 129/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.3486 - dice_coef: 0.7209 - iou: 0.5809 - val_loss: 0.4670 - val_dice_coef: 0.6270 - val_iou: 0.4575
# Epoch 130/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2959 - dice_coef: 0.7527 - iou: 0.6136 - val_loss: 0.4992 - val_dice_coef: 0.6115 - val_iou: 0.4459
# Epoch 131/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2610 - dice_coef: 0.7730 - iou: 0.6350 - val_loss: 0.5263 - val_dice_coef: 0.6026 - val_iou: 0.4428
# Epoch 132/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2940 - dice_coef: 0.7491 - iou: 0.6049 - val_loss: 0.4612 - val_dice_coef: 0.6314 - val_iou: 0.4641
# Epoch 133/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2812 - dice_coef: 0.7603 - iou: 0.6209 - val_loss: 0.5149 - val_dice_coef: 0.5983 - val_iou: 0.4292
# Epoch 134/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2936 - dice_coef: 0.7530 - iou: 0.6140 - val_loss: 0.4389 - val_dice_coef: 0.6461 - val_iou: 0.4803
# Epoch 135/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.3047 - dice_coef: 0.7424 - iou: 0.5982 - val_loss: 0.4905 - val_dice_coef: 0.6194 - val_iou: 0.4573
# Epoch 136/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2654 - dice_coef: 0.7716 - iou: 0.6369 - val_loss: 0.5096 - val_dice_coef: 0.6009 - val_iou: 0.4304
# Epoch 137/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2695 - dice_coef: 0.7685 - iou: 0.6314 - val_loss: 0.4528 - val_dice_coef: 0.6370 - val_iou: 0.4719
# Epoch 138/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2651 - dice_coef: 0.7722 - iou: 0.6365 - val_loss: 0.6593 - val_dice_coef: 0.5275 - val_iou: 0.3671
# Epoch 139/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2771 - dice_coef: 0.7627 - iou: 0.6232 - val_loss: 0.4917 - val_dice_coef: 0.6129 - val_iou: 0.4449
# Epoch 140/300
# 14/14 [==============================] - 1s 41ms/step - loss: 0.2737 - dice_coef: 0.7639 - iou: 0.6231 - val_loss: 0.5059 - val_dice_coef: 0.6114 - val_iou: 0.4462
# Epoch 141/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2777 - dice_coef: 0.7634 - iou: 0.6258 - val_loss: 0.5602 - val_dice_coef: 0.5736 - val_iou: 0.4030
# Epoch 142/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2500 - dice_coef: 0.7805 - iou: 0.6441 - val_loss: 0.4592 - val_dice_coef: 0.6320 - val_iou: 0.4653
# Epoch 143/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2386 - dice_coef: 0.7899 - iou: 0.6572 - val_loss: 0.5634 - val_dice_coef: 0.5723 - val_iou: 0.4042
# Epoch 144/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2783 - dice_coef: 0.7598 - iou: 0.6183 - val_loss: 0.5346 - val_dice_coef: 0.5873 - val_iou: 0.4186
# Epoch 145/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2789 - dice_coef: 0.7621 - iou: 0.6247 - val_loss: 0.4794 - val_dice_coef: 0.6204 - val_iou: 0.4521
# Epoch 146/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2566 - dice_coef: 0.7764 - iou: 0.6399 - val_loss: 0.5211 - val_dice_coef: 0.5965 - val_iou: 0.4278
# Epoch 147/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2860 - dice_coef: 0.7545 - iou: 0.6107 - val_loss: 0.5906 - val_dice_coef: 0.5580 - val_iou: 0.3904
# Epoch 148/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2670 - dice_coef: 0.7733 - iou: 0.6395 - val_loss: 0.6013 - val_dice_coef: 0.5526 - val_iou: 0.3878
# Epoch 149/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2599 - dice_coef: 0.7742 - iou: 0.6366 - val_loss: 0.5041 - val_dice_coef: 0.6054 - val_iou: 0.4354
# Epoch 150/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2388 - dice_coef: 0.7899 - iou: 0.6574 - val_loss: 0.5230 - val_dice_coef: 0.5939 - val_iou: 0.4235
# Epoch 151/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2364 - dice_coef: 0.7923 - iou: 0.6609 - val_loss: 0.6367 - val_dice_coef: 0.5325 - val_iou: 0.3668
# Epoch 152/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2522 - dice_coef: 0.7807 - iou: 0.6467 - val_loss: 0.4589 - val_dice_coef: 0.6325 - val_iou: 0.4655
# Epoch 153/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2521 - dice_coef: 0.7802 - iou: 0.6447 - val_loss: 0.6538 - val_dice_coef: 0.5228 - val_iou: 0.3553
# Epoch 154/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2812 - dice_coef: 0.7562 - iou: 0.6105 - val_loss: 0.4655 - val_dice_coef: 0.6337 - val_iou: 0.4730
# Epoch 155/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2489 - dice_coef: 0.7833 - iou: 0.6502 - val_loss: 0.4400 - val_dice_coef: 0.6446 - val_iou: 0.4767
# Epoch 156/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2581 - dice_coef: 0.7738 - iou: 0.6334 - val_loss: 0.5389 - val_dice_coef: 0.5858 - val_iou: 0.4177
# Epoch 157/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2322 - dice_coef: 0.7956 - iou: 0.6662 - val_loss: 0.5829 - val_dice_coef: 0.5882 - val_iou: 0.4378
# Epoch 158/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2549 - dice_coef: 0.7774 - iou: 0.6395 - val_loss: 0.4494 - val_dice_coef: 0.6388 - val_iou: 0.4706
# Epoch 159/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2687 - dice_coef: 0.7688 - iou: 0.6319 - val_loss: 0.4923 - val_dice_coef: 0.6143 - val_iou: 0.4473
# Epoch 160/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2369 - dice_coef: 0.7919 - iou: 0.6610 - val_loss: 0.5568 - val_dice_coef: 0.5800 - val_iou: 0.4138
# Epoch 161/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2414 - dice_coef: 0.7867 - iou: 0.6510 - val_loss: 0.5246 - val_dice_coef: 0.5928 - val_iou: 0.4222
# Epoch 162/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2635 - dice_coef: 0.7727 - iou: 0.6368 - val_loss: 0.6505 - val_dice_coef: 0.5226 - val_iou: 0.3536
# Epoch 163/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2564 - dice_coef: 0.7770 - iou: 0.6409 - val_loss: 0.5082 - val_dice_coef: 0.6029 - val_iou: 0.4325
# Epoch 164/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2782 - dice_coef: 0.7635 - iou: 0.6256 - val_loss: 0.6113 - val_dice_coef: 0.5440 - val_iou: 0.3769
# Epoch 165/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2453 - dice_coef: 0.7847 - iou: 0.6499 - val_loss: 0.5772 - val_dice_coef: 0.5699 - val_iou: 0.4067
# Epoch 166/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2249 - dice_coef: 0.7998 - iou: 0.6702 - val_loss: 0.5703 - val_dice_coef: 0.5657 - val_iou: 0.3953
# Epoch 167/300
# 14/14 [==============================] - 0s 36ms/step - loss: 0.2198 - dice_coef: 0.8044 - iou: 0.6763 - val_loss: 0.6460 - val_dice_coef: 0.5323 - val_iou: 0.3694
# Epoch 168/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2626 - dice_coef: 0.7706 - iou: 0.6297 - val_loss: 0.7656 - val_dice_coef: 0.4903 - val_iou: 0.3363
# Epoch 169/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2442 - dice_coef: 0.7846 - iou: 0.6481 - val_loss: 0.5802 - val_dice_coef: 0.5706 - val_iou: 0.4079
# Epoch 170/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2635 - dice_coef: 0.7710 - iou: 0.6316 - val_loss: 0.4156 - val_dice_coef: 0.6641 - val_iou: 0.5015
# Epoch 171/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2430 - dice_coef: 0.7884 - iou: 0.6577 - val_loss: 0.6043 - val_dice_coef: 0.5466 - val_iou: 0.3766
# Epoch 172/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2380 - dice_coef: 0.7906 - iou: 0.6582 - val_loss: 0.4787 - val_dice_coef: 0.6243 - val_iou: 0.4591
# Epoch 173/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2530 - dice_coef: 0.7810 - iou: 0.6480 - val_loss: 0.4155 - val_dice_coef: 0.6619 - val_iou: 0.4966
# Epoch 174/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.1787 - dice_coef: 0.8377 - iou: 0.7240 - val_loss: 0.5839 - val_dice_coef: 0.5612 - val_iou: 0.3924
# Epoch 175/300
# 14/14 [==============================] - 0s 36ms/step - loss: 0.2386 - dice_coef: 0.7911 - iou: 0.6608 - val_loss: 0.5485 - val_dice_coef: 0.5968 - val_iou: 0.4390
# Epoch 176/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2302 - dice_coef: 0.7958 - iou: 0.6641 - val_loss: 0.4667 - val_dice_coef: 0.6281 - val_iou: 0.4599
# Epoch 177/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2375 - dice_coef: 0.7910 - iou: 0.6582 - val_loss: 0.3870 - val_dice_coef: 0.6791 - val_iou: 0.5131
# Epoch 178/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2356 - dice_coef: 0.7927 - iou: 0.6620 - val_loss: 0.6213 - val_dice_coef: 0.5410 - val_iou: 0.3733
# Epoch 179/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2231 - dice_coef: 0.8028 - iou: 0.6758 - val_loss: 0.5524 - val_dice_coef: 0.5916 - val_iou: 0.4325
# Epoch 180/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2492 - dice_coef: 0.7817 - iou: 0.6463 - val_loss: 0.5358 - val_dice_coef: 0.5855 - val_iou: 0.4157
# Epoch 181/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2206 - dice_coef: 0.8051 - iou: 0.6792 - val_loss: 0.6063 - val_dice_coef: 0.5459 - val_iou: 0.3754
# Epoch 182/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2231 - dice_coef: 0.8009 - iou: 0.6702 - val_loss: 0.6455 - val_dice_coef: 0.5321 - val_iou: 0.3688
# Epoch 183/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2336 - dice_coef: 0.7940 - iou: 0.6633 - val_loss: 0.5592 - val_dice_coef: 0.5735 - val_iou: 0.4027
# Epoch 184/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2739 - dice_coef: 0.7663 - iou: 0.6292 - val_loss: 0.5474 - val_dice_coef: 0.5845 - val_iou: 0.4182
# Epoch 185/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2188 - dice_coef: 0.8057 - iou: 0.6786 - val_loss: 0.6148 - val_dice_coef: 0.5419 - val_iou: 0.3734
# Epoch 186/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2106 - dice_coef: 0.8122 - iou: 0.6885 - val_loss: 0.5714 - val_dice_coef: 0.5705 - val_iou: 0.4049
# Epoch 187/300
# 14/14 [==============================] - 0s 35ms/step - loss: 0.2225 - dice_coef: 0.8049 - iou: 0.6810 - val_loss: 0.4816 - val_dice_coef: 0.6214 - val_iou: 0.4539
# Epoch 188/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2256 - dice_coef: 0.7996 - iou: 0.6694 - val_loss: 0.6553 - val_dice_coef: 0.5208 - val_iou: 0.3545
# Epoch 189/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2422 - dice_coef: 0.7880 - iou: 0.6561 - val_loss: 0.5158 - val_dice_coef: 0.5996 - val_iou: 0.4314
# Epoch 190/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2245 - dice_coef: 0.8009 - iou: 0.6724 - val_loss: 0.5500 - val_dice_coef: 0.5803 - val_iou: 0.4121
# Epoch 191/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2863 - dice_coef: 0.7544 - iou: 0.6110 - val_loss: 0.5071 - val_dice_coef: 0.6149 - val_iou: 0.4559
# Epoch 192/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2217 - dice_coef: 0.8021 - iou: 0.6715 - val_loss: 0.4142 - val_dice_coef: 0.6624 - val_iou: 0.4974
# Epoch 193/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2205 - dice_coef: 0.8036 - iou: 0.6747 - val_loss: 0.5184 - val_dice_coef: 0.5987 - val_iou: 0.4293
# Epoch 194/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2433 - dice_coef: 0.7854 - iou: 0.6502 - val_loss: 0.5895 - val_dice_coef: 0.5577 - val_iou: 0.3893
# Epoch 195/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2002 - dice_coef: 0.8214 - iou: 0.7022 - val_loss: 0.4918 - val_dice_coef: 0.6118 - val_iou: 0.4413
# Epoch 196/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2409 - dice_coef: 0.7892 - iou: 0.6576 - val_loss: 0.5080 - val_dice_coef: 0.6096 - val_iou: 0.4458
# Epoch 197/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2121 - dice_coef: 0.8125 - iou: 0.6908 - val_loss: 0.4159 - val_dice_coef: 0.6601 - val_iou: 0.4942
# Epoch 198/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2098 - dice_coef: 0.8132 - iou: 0.6901 - val_loss: 0.4747 - val_dice_coef: 0.6237 - val_iou: 0.4530
# Epoch 199/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2008 - dice_coef: 0.8194 - iou: 0.6974 - val_loss: 0.4315 - val_dice_coef: 0.6575 - val_iou: 0.4991
# Epoch 200/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2090 - dice_coef: 0.8128 - iou: 0.6880 - val_loss: 0.6072 - val_dice_coef: 0.5450 - val_iou: 0.3754
# Epoch 201/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2126 - dice_coef: 0.8095 - iou: 0.6830 - val_loss: 0.4851 - val_dice_coef: 0.6189 - val_iou: 0.4521
# Epoch 202/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.1999 - dice_coef: 0.8199 - iou: 0.6975 - val_loss: 0.6450 - val_dice_coef: 0.5436 - val_iou: 0.3869
# Epoch 203/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.1880 - dice_coef: 0.8303 - iou: 0.7132 - val_loss: 0.5968 - val_dice_coef: 0.5722 - val_iou: 0.4182
# Epoch 204/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2055 - dice_coef: 0.8157 - iou: 0.6923 - val_loss: 0.4185 - val_dice_coef: 0.6660 - val_iou: 0.5093
# Epoch 205/300
# 14/14 [==============================] - 1s 41ms/step - loss: 0.1884 - dice_coef: 0.8289 - iou: 0.7097 - val_loss: 0.5616 - val_dice_coef: 0.5744 - val_iou: 0.4067
# Epoch 206/300
# 14/14 [==============================] - 1s 40ms/step - loss: 0.2122 - dice_coef: 0.8125 - iou: 0.6907 - val_loss: 0.6322 - val_dice_coef: 0.5326 - val_iou: 0.3641
# Epoch 207/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2234 - dice_coef: 0.8015 - iou: 0.6726 - val_loss: 0.5456 - val_dice_coef: 0.5807 - val_iou: 0.4093
# Epoch 208/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2112 - dice_coef: 0.8117 - iou: 0.6874 - val_loss: 0.6558 - val_dice_coef: 0.5284 - val_iou: 0.3663
# Epoch 209/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2099 - dice_coef: 0.8138 - iou: 0.6914 - val_loss: 0.4928 - val_dice_coef: 0.6121 - val_iou: 0.4421
# Epoch 210/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.1902 - dice_coef: 0.8289 - iou: 0.7123 - val_loss: 0.5308 - val_dice_coef: 0.5999 - val_iou: 0.4389
# Epoch 211/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.1961 - dice_coef: 0.8237 - iou: 0.7043 - val_loss: 0.6013 - val_dice_coef: 0.5569 - val_iou: 0.3926
# Epoch 212/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.2127 - dice_coef: 0.8120 - iou: 0.6894 - val_loss: 0.4749 - val_dice_coef: 0.6351 - val_iou: 0.4771
# Epoch 213/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.1933 - dice_coef: 0.8256 - iou: 0.7060 - val_loss: 0.5717 - val_dice_coef: 0.5823 - val_iou: 0.4244
# Epoch 214/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2161 - dice_coef: 0.8083 - iou: 0.6841 - val_loss: 0.6480 - val_dice_coef: 0.5358 - val_iou: 0.3744
# Epoch 215/300
# 14/14 [==============================] - 1s 41ms/step - loss: 0.1942 - dice_coef: 0.8251 - iou: 0.7065 - val_loss: 0.6945 - val_dice_coef: 0.5215 - val_iou: 0.3646
# Epoch 216/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.1944 - dice_coef: 0.8254 - iou: 0.7073 - val_loss: 0.4154 - val_dice_coef: 0.6673 - val_iou: 0.5087
# Epoch 217/300
# 14/14 [==============================] - 1s 42ms/step - loss: 0.1827 - dice_coef: 0.8345 - iou: 0.7198 - val_loss: 0.5378 - val_dice_coef: 0.6015 - val_iou: 0.4464
# Epoch 218/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.1744 - dice_coef: 0.8416 - iou: 0.7300 - val_loss: 0.8120 - val_dice_coef: 0.4446 - val_iou: 0.2872
# Epoch 219/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2164 - dice_coef: 0.8085 - iou: 0.6841 - val_loss: 0.5500 - val_dice_coef: 0.5890 - val_iou: 0.4274
# Epoch 220/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2053 - dice_coef: 0.8165 - iou: 0.6949 - val_loss: 0.4922 - val_dice_coef: 0.6149 - val_iou: 0.4468
# Epoch 221/300
# 14/14 [==============================] - 0s 37ms/step - loss: 0.2006 - dice_coef: 0.8223 - iou: 0.7057 - val_loss: 0.5849 - val_dice_coef: 0.5625 - val_iou: 0.3965
# Epoch 222/300
# 14/14 [==============================] - 1s 38ms/step - loss: 0.1974 - dice_coef: 0.8223 - iou: 0.7011 - val_loss: 0.5748 - val_dice_coef: 0.5650 - val_iou: 0.3967
# Epoch 223/300
# 14/14 [==============================] - 1s 41ms/step - loss: 0.2110 - dice_coef: 0.8134 - iou: 0.6928 - val_loss: 0.7054 - val_dice_coef: 0.5062 - val_iou: 0.3453
# Epoch 224/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2095 - dice_coef: 0.8136 - iou: 0.6910 - val_loss: 0.7389 - val_dice_coef: 0.4951 - val_iou: 0.3408
# Epoch 225/300
# 14/14 [==============================] - 1s 39ms/step - loss: 0.2250 - dice_coef: 0.8013 - iou: 0.6744 - val_loss: 0.4146 - val_dice_coef: 0.6608 - val_iou: 0.4941
# Epoch 226/300
# 14/14 [==============================] - 1s 42ms/step - loss: 0.1945 - dice_coef: 0.8261 - iou: 0.7096 - val_loss: 0.5140 - val_dice_coef: 0.6022 - val_iou: 0.4339

# %%
best_epoch = np.argmin(history.history["val_loss"])
print("Best Validation Loss: ", history.history["val_loss"][best_epoch])
print("Best Dice Coffecient (F1): ", history.history["val_dice_coef"][best_epoch])
print("Best IoU (Jaccard): ", history.history["val_iou"][best_epoch])
# Out:
# Best Validation Loss:  0.38268113136291504
# Best Dice Coffecient (F1):  0.6849384307861328
# Best IoU (Jaccard):  0.5250433683395386

# %%
t_loss = history.history['loss']
val_loss = history.history['val_loss']
acc=history.history['dice_coef']
epochs = range(1, len(acc) + 1)

plt.figure(figsize=(8, 8))
plt.plot(epochs, t_loss, 'orange', label='Train Loss')
plt.plot(epochs, val_loss, 'y', label='Validation loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Log Dice Loss')
# plt.grid()
plt.legend()

# %%
loss = history.history['loss']
acc=history.history['dice_coef']
val_acc=history.history['val_dice_coef']
epochs = range(1, len(acc) + 1)
plt.figure(figsize=(8, 8))
plt.plot(epochs, acc, 'c', label='Train')
plt.plot(epochs, val_acc, 'b', label='Validation')
plt.title('Training and Validation Dice')
plt.xlabel('Epochs')
plt.ylabel('Dice Coef')
# plt.grid()
plt.legend()

# %%
from skimage.morphology import dilation
from skimage.feature import canny
from skimage import color

# %%
for image , mask, file_name in zip(X_test[: 10], Y_test[:10], name_test[:10]):

    x_test = image.copy()
    x_test = tf.image.resize(x_test, (128, 128))/122.5 - 1.0

    mask = (mask[:, :, 0] > 225.5) + 0.0
    

    pred = (model.predict(tf.expand_dims(x_test, axis=0), verbose=0)[0] > 0.5).astype(float)
    pred = cv2.resize(pred, (256, 256))

    fig = plt.figure(figsize=(10, 4))
    ax = fig.add_subplot(1, 3, 1)
    ax.set_title('Predicted')
    edgesp = canny(pred)
    edgesp = 1.0-dilation(edgesp)
    edgesp = color.gray2rgb(1.0*edgesp)
    ax.imshow((image*edgesp).astype(int)[:, :, ::-1])


    ax = fig.add_subplot(1, 3, 2)
    ax.set_title('Correct')
    edgesc = canny(mask)
    edgesc = 1.0-dilation(edgesc)
    edgesc = color.gray2rgb(1.0*edgesc)
    ax.imshow((image*edgesc).astype(int)[:, :, ::-1])

    ax = fig.add_subplot(1, 3, 3)
    ax.set_title('Image')
    ax.imshow(image[:, :, ::-1])

# %%
for image , mask, file_name in zip(X_test[: 10], Y_test[:10], name_test[:10]):

    x_test = image.copy()
    x_test = tf.image.resize(x_test, (128, 128))/122.5 - 1.0

    mask = (mask[:, :, 0] > 225.5) + 0.0
    

    pred = (model.predict(tf.expand_dims(x_test, axis=0), verbose=0)[0] > 0.5).astype(float)
    pred = cv2.resize(pred, (256, 256))

    fig = plt.figure(figsize=(10, 4))
    ax = fig.add_subplot(1, 3, 1)
    ax.set_title('Predicted')
#     edgesp = canny(pred)
#     edgesp = 1.0-dilation(edgesp)
#     edgesp = color.gray2rgb(1.0*edgesp)
    ax.imshow(pred)


    ax = fig.add_subplot(1, 3, 2)
    ax.set_title('Correct')
#     edgesc = canny(mask)
#     edgesc = 1.0-dilation(edgesc)
#     edgesc = color.gray2rgb(1.0*edgesc)
    ax.imshow(mask)

    ax = fig.add_subplot(1, 3, 3)
    ax.set_title('Image')
    ax.imshow(image[:, :, ::-1])
